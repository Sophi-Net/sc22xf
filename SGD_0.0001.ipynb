# %%
import torch.cuda as cuda

# 检查CUDA是否可用并获取GPU数量
device_count = cuda.device_count()
print(f"Number of available GPUs: {device_count}")

# 获取每个GPU的名称
for i in range(device_count):
    device_name = cuda.get_device_name(i)
    print(f"GPU {i+1}: {device_name}")

# 获取每个GPU的显存容量
for i in range(device_count):
    device_properties = cuda.get_device_properties(i)
    print(f"GPU {i+1} Memory: {device_properties.total_memory / 1024 / 1024} MB")
# Out:
# Number of available GPUs: 4
# GPU 1: NVIDIA GeForce RTX 4090
# GPU 2: NVIDIA GeForce RTX 4090
# GPU 3: NVIDIA GeForce RTX 4090
# GPU 4: NVIDIA GeForce RTX 4090
# GPU 1 Memory: 24217.3125 MB
# GPU 2 Memory: 24217.3125 MB
# GPU 3 Memory: 24217.3125 MB
# GPU 4 Memory: 24217.3125 MB

# %%
import numpy as np
import torch.nn as nn
import torch.optim as optim
# from torch.utils.data import Dataset, DataLoader
from monai.data import DataLoader, Dataset

import sys
# import itk

import SimpleITK as sitk
import time

import torch
# import segmentation_models_pytorch as smp
from torch.nn.functional import one_hot

from tqdm import tqdm
import matplotlib.pyplot as plt
# Out:
# 2023-08-17 02:53:08.035077: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-17 02:53:09.013318: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
class Kit19Set(Dataset):
    def __init__(self, datapath, new_size, augmentation=None, preprocessing=None):
        self.datapath = datapath
        self.new_size = new_size
        self.augmentation = augmentation
        self.preprocessing = preprocessing

    def __getitem__(self, i):
        input_img_path = self.datapath+f"/case_{i:05d}/imaging.nii.gz"
        input_seg_path = self.datapath+f"/case_{i:05d}/segmentation.nii.gz"

        input_image = sitk.ReadImage(input_img_path)
        output_image = sitk.GetArrayFromImage(input_image)
        output_image = output_image.astype(np.float32)
        output_image = np.transpose(output_image, (2, 1, 0))
        output_image = torch.tensor(output_image)

        input_mask = sitk.ReadImage(input_seg_path)
        output_mask = sitk.GetArrayFromImage(input_mask)
        output_mask = output_mask.astype(np.float32)
        output_mask = np.transpose(output_mask, (2, 1, 0))
        output_mask = torch.tensor(output_mask)
        output_mask = one_hot(output_mask.long(), 3)
        output_mask = output_mask.permute(3, 1, 2, 0)


        if self.augmentation:
            sample = self.augmentation(image=output_image, mask=output_mask)
            output_image, output_mask = sample['image'], sample['mask']

        if self.preprocessing:
            sample = self.preprocessing(image=output_image, mask=output_mask)
            output_image, output_mask = sample['image'], sample['mask']

        return output_image, output_mask

    def __len__(self):
        return int(210)

# %%
new_size = [64, 128, 128]

dataset = Kit19Set("/home/featurize/data/resized_data_64_128", new_size=new_size)
train_size = int(0.8 * len(dataset))
vali_size = len(dataset) - train_size

# Use seed at 0 for reproducibility
torch.manual_seed(0)
train_dataset, vali_dataset = torch.utils.data.random_split(dataset, [train_size, vali_size])

train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True, num_workers=12)
vali_loader = DataLoader(vali_dataset, batch_size=4, shuffle=True, num_workers=12)
# dataloader = DataLoader(dataset=dataset, shuffle=False, batch_size=4)

# %%
import torch.nn.functional as F
class UNet3D(nn.Module):
    def __init__(self, in_channels=1, out_channels=3, level_channels=[64, 128, 256], bottleneck_channel=512):
        super(UNet3D, self).__init__()

        self.maxpool3d = nn.MaxPool3d(kernel_size=2, stride=2)

        # Encoder part
        self.encoder1 = self._make_encoder_block(in_channels, level_channels[0])
        self.encoder2 = self._make_encoder_block(level_channels[0], level_channels[1])
        self.encoder3 = self._make_encoder_block(level_channels[1], level_channels[2])

        # Bottleneck part
        self.bottleneck = self._make_encoder_block(level_channels[2], bottleneck_channel)

        # Decoder part
        self.upconv3 = nn.ConvTranspose3d(bottleneck_channel, bottleneck_channel, kernel_size=2, stride=2)
        self.act = nn.ReLU(inplace=True)
        self.decoder3 = self._make_decoder_block(level_channels[2]+bottleneck_channel, level_channels[2])

        self.upconv2 = nn.ConvTranspose3d(level_channels[2], level_channels[2], kernel_size=2, stride=2)
        self.decoder2 = self._make_decoder_block(level_channels[1]+level_channels[2], level_channels[1])

        self.upconv1 = nn.ConvTranspose3d(level_channels[1], level_channels[1], kernel_size=2, stride=2)
        self.decoder1 = self._make_decoder_block(level_channels[0]+level_channels[1], level_channels[0])

        # Out layer conv
        self.outlayer = nn.Conv3d(in_channels=level_channels[0], out_channels=out_channels, kernel_size=1)
        self.soft = nn.Softmax(dim=0)

    def forward(self, x):

        # Encode part
        res1 = self.encoder1(x)
        x = self.maxpool3d(res1)

        res2 = self.encoder2(x)
        x = self.maxpool3d(res2)

        res3 = self.encoder3(x)
        x = self.maxpool3d(res3)

        # Bottleneck part
        x = self.bottleneck(x)
        # x = self.act(x)

        # Decode part
        x = self.upconv3(x)
        x = torch.cat((res3, x), dim=1)
        x = self.decoder3(x)

        x = self.upconv2(x)
        x = torch.cat((res2, x), dim=1)
        x = self.decoder2(x)

        x = self.upconv1(x)
        x = torch.cat((res1, x), dim=1)
        x = self.decoder1(x)

        # Out layer
        out = self.outlayer(x)
        # print(out.shape)
        # out = self.soft(x)
        out = F.softmax(out, dim=1)
        out = out.permute(0,1,3,4,2)
        # print(out.shape)

        return out

    def _make_encoder_block(self, in_channels, out_channels):
        return nn.Sequential(
            nn.Conv3d(in_channels, out_channels//2, kernel_size=3, padding=1),
            nn.BatchNorm3d(out_channels//2),
            nn.ReLU(inplace=True),
            nn.Conv3d(out_channels//2, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm3d(out_channels),
            nn.ReLU(inplace=True)
        )

    def _make_decoder_block(self, in_channels, out_channels):
        return nn.Sequential(
            nn.Conv3d(in_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm3d(out_channels),
            nn.ReLU(inplace=True),
            nn.Conv3d(out_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm3d(out_channels),
            nn.ReLU(inplace=True)
        )

# %%
from monai.losses import DiceLoss
from monai.metrics import DiceMetric
from monai.metrics import MeanIoU
from monai.metrics import ConfusionMatrixMetric
from monai.metrics import get_confusion_matrix, compute_confusion_matrix_metric
# from monai.metrics import compute_meaniou
torch.cuda.set_device(3)
device = torch.device("cuda")
model = UNet3D()
# if device_count > 1:
#     model = nn.DataParallel(model)
#     print(f"Use {device_count} GPUs to train.")

model.to(device)

loss_function = DiceLoss(include_background=False).to(device)

train_dice_metric = DiceMetric(include_background=False, reduction="mean")
vali_dice_metric = DiceMetric(include_background=False, reduction="mean")

train_mean_iou_metric = MeanIoU(include_background=False, reduction="mean")
vali_mean_iou_metric = MeanIoU(include_background=False, reduction="mean")

# train_conf_matrix = ConfusionMatrixMetric(include_background=False, reduction="mean")


# loss_function = nn.CrossEntropyLoss()

# %%
learning_rate = 0.1
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

# %%
torch.cuda.empty_cache()
allocated_memory = torch.cuda.memory_allocated()
print(f"Allocated Memory: {allocated_memory / 1024 / 1024} MB")
cached_memory = torch.cuda.memory_cached()
print(f"Cached Memory: {cached_memory / 1024 / 1024} MB")
# Out:
# Allocated Memory: 73.54296875 MB
# Cached Memory: 80.0 MB
# /environment/miniconda3/lib/python3.10/site-packages/torch/cuda/memory.py:416: FutureWarning: torch.cuda.memory_cached has been renamed to torch.cuda.memory_reserved
#   warnings.warn(

# %%
torch.cuda.empty_cache()
# torch.autograd.set_detect_anomaly(True)
start = time.time()
best_loss = float('inf')
train_loss_list, vali_loss_list = [], []
train_dice_list, vali_dice_list = [], []
train_iou_list, vali_iou_list = [], []
epoch = 100
true_epoch = 0
for e in range(epoch):
    model.train()

    train_loss = 0.0
    cm_list = []
    # iou = 0
    train_dice_metric.reset()
    train_mean_iou_metric.reset()
    per = 0
    tqdm.write(f"Epoch {e+1}/{epoch}")
    for img, mask in train_loader:
        torch.cuda.empty_cache()
        img = img.unsqueeze(1).to(device)
        # print(img.shape)
        # mask = mask.unsqueeze(1).to(device)
        mask = mask.to(device)
        # print(f"mask shape:{mask.shape}")
        
        optimizer.zero_grad()

        out = model(img)
        # out = out.permute(0,1,3,4,2)
        # out = torch.argmax(out, dim=1)
        # print(out.shape, mask.shape)
        # print(torch.all(out == 0))
        # print((np.unique(out.cpu())))
        # print(f"out shape:{out.shape}")

        # print("forward success.")

        loss = loss_function(out, mask)
        train_loss += loss.item()
        train_dice_metric((out>0.5).float(), mask)
        train_mean_iou_metric((out>0.5).float(), mask)
        # cm = get_confusion_matrix((out>0.5).float(), mask, include_background=False)
        # cm_list.append(cm.cpu())
        
        # meaniou = compute_meaniou((out>0.5).float(), mask, include_background=False)
        # iou += meaniou.sum().item()

        
        loss.backward()
        optimizer.step()
        
        per += 1
        percentage = per/len(train_loader)
        now = '='*int(percentage*50)+'>'
        left = '*'*int((1-percentage)*50)
        percen = format(percentage*100, '.2f')
        print("\r", now + left + '\t' + f"{percen}" + '%', end="", flush=True)

        # print("optimize success.")
    epoch_loss = train_loss / len(train_loader)
    train_mean_dice = train_dice_metric.aggregate().item()
    train_mean_iou = train_mean_iou_metric.aggregate().item()
    # tqdm.write(f"Train Loss: {epoch_loss}")
    train_loss_list.append(epoch_loss)
    train_dice_list.append(train_mean_dice)
    train_iou_list.append(train_mean_iou)
    print("\ntrain dice loss is: " + f"{epoch_loss:.4f}\t" + "train mean dice is: " + f"{train_mean_dice:.4f}\t" 
          + "train mean IoU is: " + f"{train_mean_iou:.4f}")
    # cm_array = np.vstack(cm_list)
    # print(cm_array.shape)
    # total_cm = np.sum(cm_array, axis=0)
    # print(total_cm.shape)
    # total_cm = np.sum(cm_array, axis=0)
    # print(total_cm.shape)
    
    
    
    model.eval()
    eval_loss = 0.0
    vali_dice_metric.reset()
    vali_mean_iou_metric.reset()
    with torch.no_grad():
        for img, mask in vali_loader:
            torch.cuda.empty_cache()
            img = img.unsqueeze(1).to(device)
            # print(img.shape)
            # mask = mask.unsqueeze(1).to(device)
            mask = mask.to(device)

            out = model(img)
            # out = out.permute(0,1,3,4,2)

            loss = loss_function(out, mask)
            eval_loss += loss.item()
            vali_dice_metric((out>0.5).float(), mask)
            vali_mean_iou_metric((out>0.5).float(), mask)
    vali_loss = eval_loss / len(vali_loader)
    vali_mean_dice = vali_dice_metric.aggregate().item()
    vali_mean_iou = vali_mean_iou_metric.aggregate().item()
    # tqdm.write(f"Validation Loss: {vali_loss}")
    vali_loss_list.append(vali_loss)
    vali_dice_list.append(vali_mean_dice)
    vali_iou_list.append(vali_mean_iou)
    
    print(f"vali dice loss is: " + f"{vali_loss:.4f}\t" + "vali mean dice is: " + f"{vali_mean_dice:.4f}\t" 
          + "vali mean IoU is: " + f"{vali_mean_iou:.4f}\n")
    
    if vali_loss < best_loss:
        best_loss = vali_loss
        torch.save(model.state_dict(), "./SGD_0.0001/best_model.pth")
    
    true_epoch += 1

end = time.time()
print(f"Costs {end-start}s.")
# Out:
# Epoch 1/100
#  ==================================================>	100.00%
# train dice loss is: 0.9855	train mean dice is: 0.0264	train mean IoU is: 0.0137
# vali dice loss is: 0.9797	vali mean dice is: 0.0331	vali mean IoU is: 0.0172
#
# Epoch 2/100
#  ==================================================>	100.00%
# train dice loss is: 0.9784	train mean dice is: 0.0382	train mean IoU is: 0.0200
# vali dice loss is: 0.9672	vali mean dice is: 0.0582	vali mean IoU is: 0.0311
#
# Epoch 3/100
#  ==================================================>	100.00%
# train dice loss is: 0.9692	train mean dice is: 0.0593	train mean IoU is: 0.0320
# vali dice loss is: 0.9450	vali mean dice is: 0.1381	vali mean IoU is: 0.0815
#
# Epoch 4/100
#  ==================================================>	100.00%
# train dice loss is: 0.9455	train mean dice is: 0.1136	train mean IoU is: 0.0680
# vali dice loss is: 0.9963	vali mean dice is: 0.0031	vali mean IoU is: 0.0016
#
# Epoch 5/100
#  ==================================================>	100.00%
# train dice loss is: 0.8916	train mean dice is: 0.1508	train mean IoU is: 0.0975
# vali dice loss is: 0.9180	vali mean dice is: 0.0967	vali mean IoU is: 0.0572
#
# Epoch 6/100
#  ==================================================>	100.00%
# train dice loss is: 0.7842	train mean dice is: 0.2371	train mean IoU is: 0.1686
# vali dice loss is: 0.9271	vali mean dice is: 0.0765	vali mean IoU is: 0.0416
#
# Epoch 7/100
#  ==================================================>	100.00%
# train dice loss is: 0.7074	train mean dice is: 0.3035	train mean IoU is: 0.2292
# vali dice loss is: 0.7358	vali mean dice is: 0.2821	vali mean IoU is: 0.1988
#
# Epoch 8/100
#  ==================================================>	100.00%
# train dice loss is: 0.6592	train mean dice is: 0.3495	train mean IoU is: 0.2768
# vali dice loss is: 0.7384	vali mean dice is: 0.2668	vali mean IoU is: 0.1948
#
# Epoch 9/100
#  ==================================================>	100.00%
# train dice loss is: 0.6164	train mean dice is: 0.3900	train mean IoU is: 0.3253
# vali dice loss is: 0.8169	vali mean dice is: 0.1819	vali mean IoU is: 0.1225
#
# Epoch 10/100
#  ==================================================>	100.00%
# train dice loss is: 0.6047	train mean dice is: 0.4002	train mean IoU is: 0.3398
# vali dice loss is: 0.6393	vali mean dice is: 0.3597	vali mean IoU is: 0.2950
#
# Epoch 11/100
#  ==================================================>	100.00%
# train dice loss is: 0.5910	train mean dice is: 0.4132	train mean IoU is: 0.3550
# vali dice loss is: 0.5869	vali mean dice is: 0.4167	vali mean IoU is: 0.3614
#
# Epoch 12/100
#  ==================================================>	100.00%
# train dice loss is: 0.6145	train mean dice is: 0.3895	train mean IoU is: 0.3299
# vali dice loss is: 0.6562	vali mean dice is: 0.3533	vali mean IoU is: 0.2854
#
# Epoch 13/100
#  ==================================================>	100.00%
# train dice loss is: 0.5821	train mean dice is: 0.4216	train mean IoU is: 0.3671
# vali dice loss is: 0.6176	vali mean dice is: 0.3846	vali mean IoU is: 0.3240
#
# Epoch 14/100
#  ==================================================>	100.00%
# train dice loss is: 0.5689	train mean dice is: 0.4342	train mean IoU is: 0.3844
# vali dice loss is: 0.5807	vali mean dice is: 0.4227	vali mean IoU is: 0.3704
#
# Epoch 15/100
#  ==================================================>	100.00%
# train dice loss is: 0.5811	train mean dice is: 0.4218	train mean IoU is: 0.3696
# vali dice loss is: 0.5653	vali mean dice is: 0.4361	vali mean IoU is: 0.3909
#
# Epoch 16/100
#  ==================================================>	100.00%
# train dice loss is: 0.5645	train mean dice is: 0.4380	train mean IoU is: 0.3905
# vali dice loss is: 0.5885	vali mean dice is: 0.4123	vali mean IoU is: 0.3613
#
# Epoch 17/100
#  ==================================================>	100.00%
# train dice loss is: 0.5621	train mean dice is: 0.4404	train mean IoU is: 0.3934
# vali dice loss is: 0.5735	vali mean dice is: 0.4259	vali mean IoU is: 0.3787
#
# Epoch 18/100
#  ==================================================>	100.00%
# train dice loss is: 0.5568	train mean dice is: 0.4454	train mean IoU is: 0.4009
# vali dice loss is: 0.5784	vali mean dice is: 0.4217	vali mean IoU is: 0.3735
#
# Epoch 19/100
#  ==================================================>	100.00%
# train dice loss is: 0.5599	train mean dice is: 0.4422	train mean IoU is: 0.3972
# vali dice loss is: 0.5686	vali mean dice is: 0.4333	vali mean IoU is: 0.3836
#
# Epoch 20/100
#  ==================================================>	100.00%
# train dice loss is: 0.5573	train mean dice is: 0.4448	train mean IoU is: 0.4004
# vali dice loss is: 0.5963	vali mean dice is: 0.4062	vali mean IoU is: 0.3512
#
# Epoch 21/100
#  ==================================================>	100.00%
# train dice loss is: 0.5519	train mean dice is: 0.4500	train mean IoU is: 0.4076
# vali dice loss is: 0.5563	vali mean dice is: 0.4447	vali mean IoU is: 0.4021
#
# Epoch 22/100
#  ==================================================>	100.00%
# train dice loss is: 0.5470	train mean dice is: 0.4548	train mean IoU is: 0.4147
# vali dice loss is: 0.5563	vali mean dice is: 0.4456	vali mean IoU is: 0.4043
#
# Epoch 23/100
#  ==================================================>	100.00%
# train dice loss is: 0.5450	train mean dice is: 0.4567	train mean IoU is: 0.4178
# vali dice loss is: 0.5679	vali mean dice is: 0.4339	vali mean IoU is: 0.3859
#
# Epoch 24/100
#  ==================================================>	100.00%
# train dice loss is: 0.5416	train mean dice is: 0.4600	train mean IoU is: 0.4228
# vali dice loss is: 0.5923	vali mean dice is: 0.4085	vali mean IoU is: 0.3537
#
# Epoch 25/100
#  ==================================================>	100.00%
# train dice loss is: 0.5417	train mean dice is: 0.4598	train mean IoU is: 0.4225
# vali dice loss is: 0.5623	vali mean dice is: 0.4366	vali mean IoU is: 0.3943
#
# Epoch 26/100
#  ==================================================>	100.00%
# train dice loss is: 0.5406	train mean dice is: 0.4609	train mean IoU is: 0.4242
# vali dice loss is: 0.5819	vali mean dice is: 0.4253	vali mean IoU is: 0.3776
#
# Epoch 27/100
#  ==================================================>	100.00%
# train dice loss is: 0.5379	train mean dice is: 0.4635	train mean IoU is: 0.4285
# vali dice loss is: 0.5532	vali mean dice is: 0.4465	vali mean IoU is: 0.4047
#
# Epoch 28/100
#  ==================================================>	100.00%
# train dice loss is: 0.5476	train mean dice is: 0.4538	train mean IoU is: 0.4142
# vali dice loss is: 0.5637	vali mean dice is: 0.4390	vali mean IoU is: 0.3976
#
# Epoch 29/100
#  ==================================================>	100.00%
# train dice loss is: 0.5431	train mean dice is: 0.4583	train mean IoU is: 0.4203
# vali dice loss is: 0.5939	vali mean dice is: 0.4040	vali mean IoU is: 0.3571
#
# Epoch 30/100
#  ==================================================>	100.00%
# train dice loss is: 0.5389	train mean dice is: 0.4624	train mean IoU is: 0.4267
# vali dice loss is: 0.5575	vali mean dice is: 0.4419	vali mean IoU is: 0.4001
#
# Epoch 31/100
#  ==================================================>	100.00%
# train dice loss is: 0.5366	train mean dice is: 0.4646	train mean IoU is: 0.4303
# vali dice loss is: 0.5623	vali mean dice is: 0.4370	vali mean IoU is: 0.3942
#
# Epoch 32/100
#  ==================================================>	100.00%
# train dice loss is: 0.5365	train mean dice is: 0.4647	train mean IoU is: 0.4303
# vali dice loss is: 0.5548	vali mean dice is: 0.4449	vali mean IoU is: 0.4071
#
# Epoch 33/100
#  ==================================================>	100.00%
# train dice loss is: 0.5345	train mean dice is: 0.4666	train mean IoU is: 0.4335
# vali dice loss is: 0.5508	vali mean dice is: 0.4496	vali mean IoU is: 0.4091
#
# Epoch 34/100
#  ==================================================>	100.00%
# train dice loss is: 0.5345	train mean dice is: 0.4666	train mean IoU is: 0.4337
# vali dice loss is: 0.5462	vali mean dice is: 0.4534	vali mean IoU is: 0.4149
#
# Epoch 35/100
#  ==================================================>	100.00%
# train dice loss is: 0.5337	train mean dice is: 0.4674	train mean IoU is: 0.4349
# vali dice loss is: 0.5561	vali mean dice is: 0.4435	vali mean IoU is: 0.4015
#
# Epoch 36/100
#  ==================================================>	100.00%
# train dice loss is: 0.5333	train mean dice is: 0.4677	train mean IoU is: 0.4354
# vali dice loss is: 0.5547	vali mean dice is: 0.4463	vali mean IoU is: 0.4058
#
# Epoch 37/100
#  ==================================================>	100.00%
# train dice loss is: 0.5331	train mean dice is: 0.4679	train mean IoU is: 0.4356
# vali dice loss is: 0.5542	vali mean dice is: 0.4453	vali mean IoU is: 0.4037
#
# Epoch 38/100
#  ==================================================>	100.00%
# train dice loss is: 0.5330	train mean dice is: 0.4680	train mean IoU is: 0.4358
# vali dice loss is: 0.5539	vali mean dice is: 0.4456	vali mean IoU is: 0.4042
#
# Epoch 39/100
#  ==================================================>	100.00%
# train dice loss is: 0.5326	train mean dice is: 0.4685	train mean IoU is: 0.4366
# vali dice loss is: 0.5516	vali mean dice is: 0.4495	vali mean IoU is: 0.4092
#
# Epoch 40/100
#  ==================================================>	100.00%
# train dice loss is: 0.5319	train mean dice is: 0.4691	train mean IoU is: 0.4377
# vali dice loss is: 0.5630	vali mean dice is: 0.4367	vali mean IoU is: 0.3933
#
# Epoch 41/100
#  ==================================================>	100.00%
# train dice loss is: 0.5309	train mean dice is: 0.4700	train mean IoU is: 0.4392
# vali dice loss is: 0.5600	vali mean dice is: 0.4425	vali mean IoU is: 0.3990
#
# Epoch 42/100
#  ==================================================>	100.00%
# train dice loss is: 0.5307	train mean dice is: 0.4703	train mean IoU is: 0.4396
# vali dice loss is: 0.5628	vali mean dice is: 0.4359	vali mean IoU is: 0.3924
#
# Epoch 43/100
#  ==================================================>	100.00%
# train dice loss is: 0.5725	train mean dice is: 0.4294	train mean IoU is: 0.3853
# vali dice loss is: 0.5735	vali mean dice is: 0.4257	vali mean IoU is: 0.3770
#
# Epoch 44/100
#  ==================================================>	100.00%
# train dice loss is: 0.5558	train mean dice is: 0.4455	train mean IoU is: 0.4021
# vali dice loss is: 0.5641	vali mean dice is: 0.4360	vali mean IoU is: 0.3891
#
# Epoch 45/100
#  ==================================================>	100.00%
# train dice loss is: 0.5392	train mean dice is: 0.4621	train mean IoU is: 0.4262
# vali dice loss is: 0.5510	vali mean dice is: 0.4496	vali mean IoU is: 0.4084
#
# Epoch 46/100
#  ==================================================>	100.00%
# train dice loss is: 0.5349	train mean dice is: 0.4663	train mean IoU is: 0.4331
# vali dice loss is: 0.5726	vali mean dice is: 0.4342	vali mean IoU is: 0.3898
#
# Epoch 47/100
#  ==================================================>	100.00%
# train dice loss is: 0.5331	train mean dice is: 0.4681	train mean IoU is: 0.4359
# vali dice loss is: 0.5512	vali mean dice is: 0.4496	vali mean IoU is: 0.4107
#
# Epoch 48/100
#  ==================================================>	100.00%
# train dice loss is: 0.5331	train mean dice is: 0.4680	train mean IoU is: 0.4357
# vali dice loss is: 0.5537	vali mean dice is: 0.4480	vali mean IoU is: 0.4070
#
# Epoch 49/100
#  ==================================================>	100.00%
# train dice loss is: 0.5311	train mean dice is: 0.4700	train mean IoU is: 0.4392
# vali dice loss is: 0.5519	vali mean dice is: 0.4476	vali mean IoU is: 0.4081
#
# Epoch 50/100
#  ==================================================>	100.00%
# train dice loss is: 0.5383	train mean dice is: 0.4628	train mean IoU is: 0.4275
# vali dice loss is: 0.5560	vali mean dice is: 0.4442	vali mean IoU is: 0.4020
#
# Epoch 51/100
#  ==================================================>	100.00%
# train dice loss is: 0.5304	train mean dice is: 0.4705	train mean IoU is: 0.4401
# vali dice loss is: 0.5509	vali mean dice is: 0.4496	vali mean IoU is: 0.4091
#
# Epoch 52/100
#  ==================================================>	100.00%
# train dice loss is: 0.5297	train mean dice is: 0.4712	train mean IoU is: 0.4412
# vali dice loss is: 0.5497	vali mean dice is: 0.4503	vali mean IoU is: 0.4118
#
# Epoch 53/100
#  ==================================================>	100.00%
# train dice loss is: 0.5293	train mean dice is: 0.4716	train mean IoU is: 0.4419
# vali dice loss is: 0.5684	vali mean dice is: 0.4363	vali mean IoU is: 0.3916
#
# Epoch 54/100
#  ==================================================>	100.00%
# train dice loss is: 0.5286	train mean dice is: 0.4723	train mean IoU is: 0.4430
# vali dice loss is: 0.5568	vali mean dice is: 0.4425	vali mean IoU is: 0.4017
#
# Epoch 55/100
#  ==================================================>	100.00%
# train dice loss is: 0.5284	train mean dice is: 0.4724	train mean IoU is: 0.4432
# vali dice loss is: 0.5593	vali mean dice is: 0.4409	vali mean IoU is: 0.3979
#
# Epoch 56/100
#  ==================================================>	100.00%
# train dice loss is: 0.5276	train mean dice is: 0.4733	train mean IoU is: 0.4447
# vali dice loss is: 0.5572	vali mean dice is: 0.4460	vali mean IoU is: 0.4050
#
# Epoch 57/100
#  ==================================================>	100.00%
# train dice loss is: 0.5275	train mean dice is: 0.4734	train mean IoU is: 0.4447
# vali dice loss is: 0.5540	vali mean dice is: 0.4508	vali mean IoU is: 0.4121
#
# Epoch 58/100
#  ==================================================>	100.00%
# train dice loss is: 0.5277	train mean dice is: 0.4732	train mean IoU is: 0.4445
# vali dice loss is: 0.5503	vali mean dice is: 0.4491	vali mean IoU is: 0.4097
#
# Epoch 59/100
#  ==================================================>	100.00%
# train dice loss is: 0.5274	train mean dice is: 0.4734	train mean IoU is: 0.4448
# vali dice loss is: 0.5583	vali mean dice is: 0.4411	vali mean IoU is: 0.3990
#
# Epoch 60/100
#  ==================================================>	100.00%
# train dice loss is: 0.5269	train mean dice is: 0.4739	train mean IoU is: 0.4457
# vali dice loss is: 0.5552	vali mean dice is: 0.4464	vali mean IoU is: 0.4064
#
# Epoch 61/100
#  ==================================================>	100.00%
# train dice loss is: 0.5269	train mean dice is: 0.4739	train mean IoU is: 0.4456
# vali dice loss is: 0.5512	vali mean dice is: 0.4491	vali mean IoU is: 0.4098
#
# Epoch 62/100
#  ==================================================>	100.00%
# train dice loss is: 0.5265	train mean dice is: 0.4743	train mean IoU is: 0.4462
# vali dice loss is: 0.5517	vali mean dice is: 0.4477	vali mean IoU is: 0.4081
#
# Epoch 63/100
#  ==================================================>	100.00%
# train dice loss is: 0.5270	train mean dice is: 0.4738	train mean IoU is: 0.4455
# vali dice loss is: 0.5449	vali mean dice is: 0.4553	vali mean IoU is: 0.4174
#
# Epoch 64/100
#  ==================================================>	100.00%
# train dice loss is: 0.5264	train mean dice is: 0.4744	train mean IoU is: 0.4465
# vali dice loss is: 0.5489	vali mean dice is: 0.4519	vali mean IoU is: 0.4132
#
# Epoch 65/100
#  ==================================================>	100.00%
# train dice loss is: 0.5254	train mean dice is: 0.4753	train mean IoU is: 0.4481
# vali dice loss is: 0.5601	vali mean dice is: 0.4389	vali mean IoU is: 0.3949
#
# Epoch 66/100
#  ==================================================>	100.00%
# train dice loss is: 0.5259	train mean dice is: 0.4749	train mean IoU is: 0.4473
# vali dice loss is: 0.5557	vali mean dice is: 0.4434	vali mean IoU is: 0.4012
#
# Epoch 67/100
#  ==================================================>	100.00%
# train dice loss is: 0.5249	train mean dice is: 0.4759	train mean IoU is: 0.4490
# vali dice loss is: 0.5570	vali mean dice is: 0.4480	vali mean IoU is: 0.4085
#
# Epoch 68/100
#  ==================================================>	100.00%
# train dice loss is: 0.5251	train mean dice is: 0.4756	train mean IoU is: 0.4486
# vali dice loss is: 0.5547	vali mean dice is: 0.4478	vali mean IoU is: 0.4084
#
# Epoch 69/100
#  ==================================================>	100.00%
# train dice loss is: 0.5246	train mean dice is: 0.4761	train mean IoU is: 0.4494
# vali dice loss is: 0.5639	vali mean dice is: 0.4380	vali mean IoU is: 0.3946
#
# Epoch 70/100
#  ==================================================>	100.00%
# train dice loss is: 0.5251	train mean dice is: 0.4756	train mean IoU is: 0.4486
# vali dice loss is: 0.5562	vali mean dice is: 0.4452	vali mean IoU is: 0.4039
#
# Epoch 71/100
#  ==================================================>	100.00%
# train dice loss is: 0.5245	train mean dice is: 0.4762	train mean IoU is: 0.4496
# vali dice loss is: 0.5526	vali mean dice is: 0.4476	vali mean IoU is: 0.4071
#
# Epoch 72/100
#  ==================================================>	100.00%
# train dice loss is: 0.5249	train mean dice is: 0.4758	train mean IoU is: 0.4488
# vali dice loss is: 0.5584	vali mean dice is: 0.4425	vali mean IoU is: 0.4012
#
# Epoch 73/100
#  ==================================================>	100.00%
# train dice loss is: 0.5244	train mean dice is: 0.4763	train mean IoU is: 0.4496
# vali dice loss is: 0.5574	vali mean dice is: 0.4440	vali mean IoU is: 0.4029
#
# Epoch 74/100
#  ==================================================>	100.00%
# train dice loss is: 0.5242	train mean dice is: 0.4765	train mean IoU is: 0.4501
# vali dice loss is: 0.5586	vali mean dice is: 0.4407	vali mean IoU is: 0.3988
#
# Epoch 75/100
#  ==================================================>	100.00%
# train dice loss is: 0.5241	train mean dice is: 0.4766	train mean IoU is: 0.4503
# vali dice loss is: 0.5541	vali mean dice is: 0.4466	vali mean IoU is: 0.4059
#
# Epoch 76/100
#  ==================================================>	100.00%
# train dice loss is: 0.5245	train mean dice is: 0.4762	train mean IoU is: 0.4495
# vali dice loss is: 0.5530	vali mean dice is: 0.4463	vali mean IoU is: 0.4055
#
# Epoch 77/100
#  ==================================================>	100.00%
# train dice loss is: 0.5238	train mean dice is: 0.4768	train mean IoU is: 0.4505
# vali dice loss is: 0.5515	vali mean dice is: 0.4487	vali mean IoU is: 0.4100
#
# Epoch 78/100
#  ==================================================>	100.00%
# train dice loss is: 0.5237	train mean dice is: 0.4771	train mean IoU is: 0.4510
# vali dice loss is: 0.5647	vali mean dice is: 0.4356	vali mean IoU is: 0.3918
#
# Epoch 79/100
#  ==================================================>	100.00%
# train dice loss is: 0.5235	train mean dice is: 0.4772	train mean IoU is: 0.4511
# vali dice loss is: 0.5463	vali mean dice is: 0.4531	vali mean IoU is: 0.4149
#
# Epoch 80/100
#  ==================================================>	100.00%
# train dice loss is: 0.5232	train mean dice is: 0.4775	train mean IoU is: 0.4518
# vali dice loss is: 0.5578	vali mean dice is: 0.4429	vali mean IoU is: 0.4011
#
# Epoch 81/100
#  ==================================================>	100.00%
# train dice loss is: 0.5228	train mean dice is: 0.4779	train mean IoU is: 0.4523
# vali dice loss is: 0.5597	vali mean dice is: 0.4403	vali mean IoU is: 0.3971
#
# Epoch 82/100
#  ==================================================>	100.00%
# train dice loss is: 0.5228	train mean dice is: 0.4779	train mean IoU is: 0.4523
# vali dice loss is: 0.5450	vali mean dice is: 0.4546	vali mean IoU is: 0.4170
#
# Epoch 83/100
#  ==================================================>	100.00%
# train dice loss is: 0.5224	train mean dice is: 0.4782	train mean IoU is: 0.4529
# vali dice loss is: 0.5537	vali mean dice is: 0.4457	vali mean IoU is: 0.4040
#
# Epoch 84/100
#  ==================================================>	100.00%
# train dice loss is: 0.5221	train mean dice is: 0.4785	train mean IoU is: 0.4535
# vali dice loss is: 0.5514	vali mean dice is: 0.4477	vali mean IoU is: 0.4072
#
# Epoch 85/100
#  ==================================================>	100.00%
# train dice loss is: 0.5222	train mean dice is: 0.4784	train mean IoU is: 0.4533
# vali dice loss is: 0.5519	vali mean dice is: 0.4471	vali mean IoU is: 0.4065
#
# Epoch 86/100
#  ==================================================>	100.00%
# train dice loss is: 0.5218	train mean dice is: 0.4788	train mean IoU is: 0.4539
# vali dice loss is: 0.5545	vali mean dice is: 0.4462	vali mean IoU is: 0.4053
#
# Epoch 87/100
#  ==================================================>	100.00%
# train dice loss is: 0.5219	train mean dice is: 0.4788	train mean IoU is: 0.4539
# vali dice loss is: 0.5570	vali mean dice is: 0.4420	vali mean IoU is: 0.3993
#
# Epoch 88/100
#  ==================================================>	100.00%
# train dice loss is: 0.5215	train mean dice is: 0.4791	train mean IoU is: 0.4545
# vali dice loss is: 0.5532	vali mean dice is: 0.4473	vali mean IoU is: 0.4070
#
# Epoch 89/100
#  ==================================================>	100.00%
# train dice loss is: 0.5218	train mean dice is: 0.4789	train mean IoU is: 0.4540
# vali dice loss is: 0.5520	vali mean dice is: 0.4470	vali mean IoU is: 0.4074
#
# Epoch 90/100
#  ==================================================>	100.00%
# train dice loss is: 0.5214	train mean dice is: 0.4792	train mean IoU is: 0.4546
# vali dice loss is: 0.5534	vali mean dice is: 0.4474	vali mean IoU is: 0.4077
#
# Epoch 91/100
#  ==================================================>	100.00%
# train dice loss is: 0.5212	train mean dice is: 0.4794	train mean IoU is: 0.4549
# vali dice loss is: 0.5599	vali mean dice is: 0.4416	vali mean IoU is: 0.3991
#
# Epoch 92/100
#  ==================================================>	100.00%
# train dice loss is: 0.5209	train mean dice is: 0.4797	train mean IoU is: 0.4555
# vali dice loss is: 0.5489	vali mean dice is: 0.4507	vali mean IoU is: 0.4121
#
# Epoch 93/100
#  ==================================================>	100.00%
# train dice loss is: 0.5208	train mean dice is: 0.4798	train mean IoU is: 0.4556
# vali dice loss is: 0.5515	vali mean dice is: 0.4488	vali mean IoU is: 0.4088
#
# Epoch 94/100
#  ==================================================>	100.00%
# train dice loss is: 0.5204	train mean dice is: 0.4802	train mean IoU is: 0.4563
# vali dice loss is: 0.5489	vali mean dice is: 0.4513	vali mean IoU is: 0.4127
#
# Epoch 95/100
#  ==================================================>	100.00%
# train dice loss is: 0.5209	train mean dice is: 0.4797	train mean IoU is: 0.4554
# vali dice loss is: 0.5529	vali mean dice is: 0.4465	vali mean IoU is: 0.4057
#
# Epoch 96/100
#  ==================================================>	100.00%
# train dice loss is: 0.5202	train mean dice is: 0.4805	train mean IoU is: 0.4568
# vali dice loss is: 0.5528	vali mean dice is: 0.4460	vali mean IoU is: 0.4051
#
# Epoch 97/100
#  ==================================================>	100.00%
# train dice loss is: 0.5205	train mean dice is: 0.4802	train mean IoU is: 0.4562
# vali dice loss is: 0.5498	vali mean dice is: 0.4517	vali mean IoU is: 0.4127
#
# Epoch 98/100
#  ==================================================>	100.00%
# train dice loss is: 0.5198	train mean dice is: 0.4808	train mean IoU is: 0.4574
# vali dice loss is: 0.5639	vali mean dice is: 0.4347	vali mean IoU is: 0.3896
#
# Epoch 99/100
#  ==================================================>	100.00%
# train dice loss is: 0.5199	train mean dice is: 0.4807	train mean IoU is: 0.4571
# vali dice loss is: 0.5534	vali mean dice is: 0.4466	vali mean IoU is: 0.4058
#
# Epoch 100/100
#  ==================================================>	100.00%
# train dice loss is: 0.5203	train mean dice is: 0.4803	train mean IoU is: 0.4565
# vali dice loss is: 0.5551	vali mean dice is: 0.4476	vali mean IoU is: 0.4076
#
# Costs 4960.417934179306s.

# %%
plt.figure()
x = range(1, true_epoch+1)
# print(true_epoch)
loss1, loss2 = train_loss_list, vali_loss_list
# print(loss1)
plt.title(f'train loss vs vali loss, epoch={true_epoch}, learning rate={learning_rate}, optimizer=SGD')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.plot(x, loss1, label='train loss')
plt.plot(x, loss2, label='vali loss')
plt.legend()
plt.savefig('./SGD_0.0001/loss_plot.png')
plt.show()

# %%
plt.figure()
x = range(1, true_epoch+1)
# print(true_epoch)
loss1, loss2 = train_dice_list, vali_dice_list
# print(loss1)
plt.title(f'train dice vs vali dice, epoch={true_epoch}, learning rate={learning_rate}, optimizer=SGD')
plt.xlabel('epoch')
plt.ylabel('dice score')
plt.plot(x, loss1, label='train dice')
plt.plot(x, loss2, label='vali dice')
plt.legend()
plt.savefig('./SGD_0.0001/dice_plot.png')
plt.show()

# %%
plt.figure()
x = range(1, true_epoch+1)
# print(true_epoch)
loss1, loss2 = train_iou_list, vali_iou_list
# print(loss1)
plt.title(f'train IoU vs vali IoU, epoch={true_epoch}, learning rate={learning_rate}, optimizer=SGD')
plt.xlabel('epoch')
plt.ylabel('IoU')
plt.plot(x, loss1, label='train IoU')
plt.plot(x, loss2, label='vali IoU')
plt.legend()
plt.savefig('./SGD_0.0001/IoU_plot.png')
plt.show()

# %%
import os
class TestKit19Set(Dataset):
    def __init__(self, datapath, new_size, augmentation=None, preprocessing=None):
        self.datapath = datapath
        self.new_size = new_size
        self.augmentation = augmentation
        self.preprocessing = preprocessing

    def __getitem__(self, i):
        input_img_path = self.datapath+f"/case_{i+210:05d}/imaging.nii.gz"
        # input_seg_path = self.datapath+f"/case_{i:05d}/segmentation.nii.gz"

        input_image = sitk.ReadImage(input_img_path)
        # print(type(input_image))

        # Get the current spacing and size of the input image
        input_spacing = input_image.GetSpacing()
        input_size = input_image.GetSize()

        # Compute the desired spacing based on the new size
        new_spacing = [old_sz * old_spc / new_sz for old_sz, old_spc, new_sz in
                       zip(input_size, input_spacing, self.new_size)]

        # Create the resampling transformation
        resampler = sitk.ResampleImageFilter()
        resampler.SetSize(self.new_size)
        resampler.SetOutputSpacing(new_spacing)
        resampler.SetOutputOrigin(input_image.GetOrigin())
        resampler.SetOutputDirection(input_image.GetDirection())

        # Perform the resampling
        output_image = resampler.Execute(input_image)
        # folder_path = f"/test_visual/case_{i + 210:05d}"
        # if not os.path.exists(folder_path):
            # os.makedirs(folder_path)
        output_filename = f"./test_visual/case_{i + 210:05d}/imaging.nii.gz"
        sitk.WriteImage(output_image, output_filename)
        output_image = sitk.GetArrayFromImage(output_image)
        output_image = output_image.astype(np.float32)
        output_image = np.transpose(output_image, (2, 1, 0))

        return output_image
        # return output_image, output_mask

    def __len__(self):
        return int(90)

# %%
test_set = TestKit19Set("data", new_size=[64, 256, 256])
test_loader = DataLoader(test_set, batch_size=1, shuffle=False)

# %%
device = torch.device("cuda")
model = UNet3D()
model.load_state_dict(torch.load("./work/new_best_model_3.pth"))

model.to(device)

from tqdm.notebook import tqdm_notebook
torch.cuda.empty_cache()
tqdm_notebook.monitor_interval = 0
for i, img in tqdm_notebook(enumerate(test_loader),desc="Batch progress", leave=False):
    with torch.no_grad():
        img = img.unsqueeze(1).to(device)
        # print(img.shape)
        out = model(img)
        # print(out.shape)
        out = torch.squeeze(out)
        out = out.permute(0,3,1,2)
        # print(out.shape)
        # print(out.shape)
        # print(out[0,24,24,24], out[1,24,24,24],out[2,24,24,24])
        # print(out[0, 36, 36, 36], out[1, 36, 36, 36], out[2, 36, 36, 36])
        # the output shape is [3, 64, 128,128]

        out = torch.argmax(out, dim=0)
        # the shape will be [64,128,128]
        # print(out.shape)
        # is_all_zero = torch.all(out == 0)
        # print("Is the tensor all zero?", is_all_zero)
        # print(out.shape)
        # unique = np.unique(out)
        # print(len(unique))
        
        out = out.cpu()
        out = out.detach().numpy()
        out = np.transpose(out, (2, 1, 0))
        # unique = np.unique(out)
        # print(out.shape)
        out = sitk.GetImageFromArray(out)
        # print(out.GetSize(), type(out))
        output_filename = f"./test_visual/case_{i+210:05d}/segmentation.nii.gz"
        # print(output_filename)
        sitk.WriteImage(out, output_filename)
# Out:
# Batch progress: 0it [00:00, ?it/s]
