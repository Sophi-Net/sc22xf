# %%
import torch.cuda as cuda

# 检查CUDA是否可用并获取GPU数量
device_count = cuda.device_count()
print(f"Number of available GPUs: {device_count}")

# 获取每个GPU的名称
for i in range(device_count):
    device_name = cuda.get_device_name(i)
    print(f"GPU {i+1}: {device_name}")

# 获取每个GPU的显存容量
for i in range(device_count):
    device_properties = cuda.get_device_properties(i)
    print(f"GPU {i+1} Memory: {device_properties.total_memory / 1024 / 1024} MB")
# Out:
# Number of available GPUs: 4
# GPU 1: NVIDIA GeForce RTX 4090
# GPU 2: NVIDIA GeForce RTX 4090
# GPU 3: NVIDIA GeForce RTX 4090
# GPU 4: NVIDIA GeForce RTX 4090
# GPU 1 Memory: 24217.3125 MB
# GPU 2 Memory: 24217.3125 MB
# GPU 3 Memory: 24217.3125 MB
# GPU 4 Memory: 24217.3125 MB

# %%
import numpy as np
import torch.nn as nn
import torch.optim as optim
# from torch.utils.data import Dataset, DataLoader
from monai.data import DataLoader, Dataset

import sys
# import itk

import SimpleITK as sitk
import time

import torch
# import segmentation_models_pytorch as smp
from torch.nn.functional import one_hot

from tqdm import tqdm
import matplotlib.pyplot as plt
# Out:
# 2023-08-17 02:43:56.868825: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-17 02:43:57.914895: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
class Kit19Set(Dataset):
    def __init__(self, datapath, new_size, augmentation=None, preprocessing=None):
        self.datapath = datapath
        self.new_size = new_size
        self.augmentation = augmentation
        self.preprocessing = preprocessing

    def __getitem__(self, i):
        input_img_path = self.datapath+f"/case_{i:05d}/imaging.nii.gz"
        input_seg_path = self.datapath+f"/case_{i:05d}/segmentation.nii.gz"

        input_image = sitk.ReadImage(input_img_path)
        output_image = sitk.GetArrayFromImage(input_image)
        output_image = output_image.astype(np.float32)
        output_image = np.transpose(output_image, (2, 1, 0))
        output_image = torch.tensor(output_image)

        input_mask = sitk.ReadImage(input_seg_path)
        output_mask = sitk.GetArrayFromImage(input_mask)
        output_mask = output_mask.astype(np.float32)
        output_mask = np.transpose(output_mask, (2, 1, 0))
        output_mask = torch.tensor(output_mask)
        output_mask = one_hot(output_mask.long(), 3)
        output_mask = output_mask.permute(3, 1, 2, 0)


        if self.augmentation:
            sample = self.augmentation(image=output_image, mask=output_mask)
            output_image, output_mask = sample['image'], sample['mask']

        if self.preprocessing:
            sample = self.preprocessing(image=output_image, mask=output_mask)
            output_image, output_mask = sample['image'], sample['mask']

        return output_image, output_mask

    def __len__(self):
        return int(210)

# %%
new_size = [64, 128, 128]

dataset = Kit19Set("/home/featurize/data/resized_data_64_128", new_size=new_size)
train_size = int(0.8 * len(dataset))
vali_size = len(dataset) - train_size

# Use seed at 0 for reproducibility
torch.manual_seed(0)
train_dataset, vali_dataset = torch.utils.data.random_split(dataset, [train_size, vali_size])

train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True, num_workers=12)
vali_loader = DataLoader(vali_dataset, batch_size=4, shuffle=True, num_workers=12)
# dataloader = DataLoader(dataset=dataset, shuffle=False, batch_size=4)

# %%
import torch.nn.functional as F
class UNet3D(nn.Module):
    def __init__(self, in_channels=1, out_channels=3, level_channels=[64, 128, 256], bottleneck_channel=512):
        super(UNet3D, self).__init__()

        self.maxpool3d = nn.MaxPool3d(kernel_size=2, stride=2)

        # Encoder part
        self.encoder1 = self._make_encoder_block(in_channels, level_channels[0])
        self.encoder2 = self._make_encoder_block(level_channels[0], level_channels[1])
        self.encoder3 = self._make_encoder_block(level_channels[1], level_channels[2])

        # Bottleneck part
        self.bottleneck = self._make_encoder_block(level_channels[2], bottleneck_channel)

        # Decoder part
        self.upconv3 = nn.ConvTranspose3d(bottleneck_channel, bottleneck_channel, kernel_size=2, stride=2)
        self.act = nn.ReLU(inplace=True)
        self.decoder3 = self._make_decoder_block(level_channels[2]+bottleneck_channel, level_channels[2])

        self.upconv2 = nn.ConvTranspose3d(level_channels[2], level_channels[2], kernel_size=2, stride=2)
        self.decoder2 = self._make_decoder_block(level_channels[1]+level_channels[2], level_channels[1])

        self.upconv1 = nn.ConvTranspose3d(level_channels[1], level_channels[1], kernel_size=2, stride=2)
        self.decoder1 = self._make_decoder_block(level_channels[0]+level_channels[1], level_channels[0])

        # Out layer conv
        self.outlayer = nn.Conv3d(in_channels=level_channels[0], out_channels=out_channels, kernel_size=1)
        self.soft = nn.Softmax(dim=0)

    def forward(self, x):

        # Encode part
        res1 = self.encoder1(x)
        x = self.maxpool3d(res1)

        res2 = self.encoder2(x)
        x = self.maxpool3d(res2)

        res3 = self.encoder3(x)
        x = self.maxpool3d(res3)

        # Bottleneck part
        x = self.bottleneck(x)
        # x = self.act(x)

        # Decode part
        x = self.upconv3(x)
        x = torch.cat((res3, x), dim=1)
        x = self.decoder3(x)

        x = self.upconv2(x)
        x = torch.cat((res2, x), dim=1)
        x = self.decoder2(x)

        x = self.upconv1(x)
        x = torch.cat((res1, x), dim=1)
        x = self.decoder1(x)

        # Out layer
        out = self.outlayer(x)
        # print(out.shape)
        # out = self.soft(x)
        out = F.softmax(out, dim=1)
        out = out.permute(0,1,3,4,2)
        # print(out.shape)

        return out

    def _make_encoder_block(self, in_channels, out_channels):
        return nn.Sequential(
            nn.Conv3d(in_channels, out_channels//2, kernel_size=3, padding=1),
            nn.BatchNorm3d(out_channels//2),
            nn.ReLU(inplace=True),
            nn.Conv3d(out_channels//2, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm3d(out_channels),
            nn.ReLU(inplace=True)
        )

    def _make_decoder_block(self, in_channels, out_channels):
        return nn.Sequential(
            nn.Conv3d(in_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm3d(out_channels),
            nn.ReLU(inplace=True),
            nn.Conv3d(out_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm3d(out_channels),
            nn.ReLU(inplace=True)
        )

# %%
from monai.losses import DiceLoss
from monai.metrics import DiceMetric
from monai.metrics import MeanIoU
from monai.metrics import ConfusionMatrixMetric
from monai.metrics import get_confusion_matrix, compute_confusion_matrix_metric
# from monai.metrics import compute_meaniou
torch.cuda.set_device(2)
device = torch.device("cuda")
model = UNet3D()
# if device_count > 1:
#     model = nn.DataParallel(model)
#     print(f"Use {device_count} GPUs to train.")

model.to(device)

loss_function = DiceLoss(include_background=False).to(device)

train_dice_metric = DiceMetric(include_background=False, reduction="mean")
vali_dice_metric = DiceMetric(include_background=False, reduction="mean")

train_mean_iou_metric = MeanIoU(include_background=False, reduction="mean")
vali_mean_iou_metric = MeanIoU(include_background=False, reduction="mean")

# train_conf_matrix = ConfusionMatrixMetric(include_background=False, reduction="mean")


# loss_function = nn.CrossEntropyLoss()

# %%
learning_rate = 0.01
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

# %%
torch.cuda.empty_cache()
allocated_memory = torch.cuda.memory_allocated()
print(f"Allocated Memory: {allocated_memory / 1024 / 1024} MB")
cached_memory = torch.cuda.memory_cached()
print(f"Cached Memory: {cached_memory / 1024 / 1024} MB")
# Out:
# Allocated Memory: 73.54296875 MB
# Cached Memory: 80.0 MB
# /environment/miniconda3/lib/python3.10/site-packages/torch/cuda/memory.py:416: FutureWarning: torch.cuda.memory_cached has been renamed to torch.cuda.memory_reserved
#   warnings.warn(

# %%
torch.cuda.empty_cache()
# torch.autograd.set_detect_anomaly(True)
start = time.time()
best_loss = float('inf')
train_loss_list, vali_loss_list = [], []
train_dice_list, vali_dice_list = [], []
train_iou_list, vali_iou_list = [], []
epoch = 100
true_epoch = 0
for e in range(epoch):
    model.train()

    train_loss = 0.0
    cm_list = []
    # iou = 0
    train_dice_metric.reset()
    train_mean_iou_metric.reset()
    per = 0
    tqdm.write(f"Epoch {e+1}/{epoch}")
    for img, mask in train_loader:
        torch.cuda.empty_cache()
        img = img.unsqueeze(1).to(device)
        # print(img.shape)
        # mask = mask.unsqueeze(1).to(device)
        mask = mask.to(device)
        # print(f"mask shape:{mask.shape}")
        
        optimizer.zero_grad()

        out = model(img)
        # out = out.permute(0,1,3,4,2)
        # out = torch.argmax(out, dim=1)
        # print(out.shape, mask.shape)
        # print(torch.all(out == 0))
        # print((np.unique(out.cpu())))
        # print(f"out shape:{out.shape}")

        # print("forward success.")

        loss = loss_function(out, mask)
        train_loss += loss.item()
        train_dice_metric((out>0.5).float(), mask)
        train_mean_iou_metric((out>0.5).float(), mask)
        # cm = get_confusion_matrix((out>0.5).float(), mask, include_background=False)
        # cm_list.append(cm.cpu())
        
        # meaniou = compute_meaniou((out>0.5).float(), mask, include_background=False)
        # iou += meaniou.sum().item()

        
        loss.backward()
        optimizer.step()
        
        per += 1
        percentage = per/len(train_loader)
        now = '='*int(percentage*50)+'>'
        left = '*'*int((1-percentage)*50)
        percen = format(percentage*100, '.2f')
        print("\r", now + left + '\t' + f"{percen}" + '%', end="", flush=True)

        # print("optimize success.")
    epoch_loss = train_loss / len(train_loader)
    train_mean_dice = train_dice_metric.aggregate().item()
    train_mean_iou = train_mean_iou_metric.aggregate().item()
    # tqdm.write(f"Train Loss: {epoch_loss}")
    train_loss_list.append(epoch_loss)
    train_dice_list.append(train_mean_dice)
    train_iou_list.append(train_mean_iou)
    print("\ntrain dice loss is: " + f"{epoch_loss:.4f}\t" + "train mean dice is: " + f"{train_mean_dice:.4f}\t" 
          + "train mean IoU is: " + f"{train_mean_iou:.4f}")
    # cm_array = np.vstack(cm_list)
    # print(cm_array.shape)
    # total_cm = np.sum(cm_array, axis=0)
    # print(total_cm.shape)
    # total_cm = np.sum(cm_array, axis=0)
    # print(total_cm.shape)
    
    
    
    model.eval()
    eval_loss = 0.0
    vali_dice_metric.reset()
    vali_mean_iou_metric.reset()
    with torch.no_grad():
        for img, mask in vali_loader:
            torch.cuda.empty_cache()
            img = img.unsqueeze(1).to(device)
            # print(img.shape)
            # mask = mask.unsqueeze(1).to(device)
            mask = mask.to(device)

            out = model(img)
            # out = out.permute(0,1,3,4,2)

            loss = loss_function(out, mask)
            eval_loss += loss.item()
            vali_dice_metric((out>0.5).float(), mask)
            vali_mean_iou_metric((out>0.5).float(), mask)
    vali_loss = eval_loss / len(vali_loader)
    vali_mean_dice = vali_dice_metric.aggregate().item()
    vali_mean_iou = vali_mean_iou_metric.aggregate().item()
    # tqdm.write(f"Validation Loss: {vali_loss}")
    vali_loss_list.append(vali_loss)
    vali_dice_list.append(vali_mean_dice)
    vali_iou_list.append(vali_mean_iou)
    
    print(f"vali dice loss is: " + f"{vali_loss:.4f}\t" + "vali mean dice is: " + f"{vali_mean_dice:.4f}\t" 
          + "vali mean IoU is: " + f"{vali_mean_iou:.4f}\n")
    
    if vali_loss < best_loss:
        best_loss = vali_loss
        torch.save(model.state_dict(), "./SGD_0.01/best_model.pth")
    
    true_epoch += 1

end = time.time()
print(f"Costs {end-start}s.")
# Out:
# Epoch 1/100
#  ==================================================>	100.00%
# train dice loss is: 0.9902	train mean dice is: 0.0201	train mean IoU is: 0.0104
# vali dice loss is: 0.9873	vali mean dice is: 0.0357	vali mean IoU is: 0.0186
#
# Epoch 2/100
#  ==================================================>	100.00%
# train dice loss is: 0.9883	train mean dice is: 0.0253	train mean IoU is: 0.0130
# vali dice loss is: 0.9850	vali mean dice is: 0.0284	vali mean IoU is: 0.0146
#
# Epoch 3/100
#  ==================================================>	100.00%
# train dice loss is: 0.9871	train mean dice is: 0.0245	train mean IoU is: 0.0126
# vali dice loss is: 0.9836	vali mean dice is: 0.0282	vali mean IoU is: 0.0146
#
# Epoch 4/100
#  ==================================================>	100.00%
# train dice loss is: 0.9863	train mean dice is: 0.0248	train mean IoU is: 0.0128
# vali dice loss is: 0.9823	vali mean dice is: 0.0297	vali mean IoU is: 0.0154
#
# Epoch 5/100
#  ==================================================>	100.00%
# train dice loss is: 0.9855	train mean dice is: 0.0257	train mean IoU is: 0.0132
# vali dice loss is: 0.9818	vali mean dice is: 0.0310	vali mean IoU is: 0.0161
#
# Epoch 6/100
#  ==================================================>	100.00%
# train dice loss is: 0.9848	train mean dice is: 0.0272	train mean IoU is: 0.0141
# vali dice loss is: 0.9810	vali mean dice is: 0.0321	vali mean IoU is: 0.0167
#
# Epoch 7/100
#  ==================================================>	100.00%
# train dice loss is: 0.9842	train mean dice is: 0.0280	train mean IoU is: 0.0145
# vali dice loss is: 0.9804	vali mean dice is: 0.0335	vali mean IoU is: 0.0174
#
# Epoch 8/100
#  ==================================================>	100.00%
# train dice loss is: 0.9835	train mean dice is: 0.0295	train mean IoU is: 0.0153
# vali dice loss is: 0.9787	vali mean dice is: 0.0350	vali mean IoU is: 0.0182
#
# Epoch 9/100
#  ==================================================>	100.00%
# train dice loss is: 0.9828	train mean dice is: 0.0304	train mean IoU is: 0.0158
# vali dice loss is: 0.9778	vali mean dice is: 0.0402	vali mean IoU is: 0.0211
#
# Epoch 10/100
#  ==================================================>	100.00%
# train dice loss is: 0.9821	train mean dice is: 0.0324	train mean IoU is: 0.0169
# vali dice loss is: 0.9770	vali mean dice is: 0.0419	vali mean IoU is: 0.0220
#
# Epoch 11/100
#  ==================================================>	100.00%
# train dice loss is: 0.9814	train mean dice is: 0.0341	train mean IoU is: 0.0178
# vali dice loss is: 0.9760	vali mean dice is: 0.0402	vali mean IoU is: 0.0211
#
# Epoch 12/100
#  ==================================================>	100.00%
# train dice loss is: 0.9807	train mean dice is: 0.0347	train mean IoU is: 0.0181
# vali dice loss is: 0.9751	vali mean dice is: 0.0460	vali mean IoU is: 0.0243
#
# Epoch 13/100
#  ==================================================>	100.00%
# train dice loss is: 0.9799	train mean dice is: 0.0360	train mean IoU is: 0.0188
# vali dice loss is: 0.9727	vali mean dice is: 0.0492	vali mean IoU is: 0.0261
#
# Epoch 14/100
#  ==================================================>	100.00%
# train dice loss is: 0.9792	train mean dice is: 0.0385	train mean IoU is: 0.0202
# vali dice loss is: 0.9735	vali mean dice is: 0.0466	vali mean IoU is: 0.0246
#
# Epoch 15/100
#  ==================================================>	100.00%
# train dice loss is: 0.9786	train mean dice is: 0.0390	train mean IoU is: 0.0204
# vali dice loss is: 0.9719	vali mean dice is: 0.0471	vali mean IoU is: 0.0249
#
# Epoch 16/100
#  ==================================================>	100.00%
# train dice loss is: 0.9777	train mean dice is: 0.0402	train mean IoU is: 0.0211
# vali dice loss is: 0.9703	vali mean dice is: 0.0625	vali mean IoU is: 0.0337
#
# Epoch 17/100
#  ==================================================>	100.00%
# train dice loss is: 0.9769	train mean dice is: 0.0430	train mean IoU is: 0.0226
# vali dice loss is: 0.9700	vali mean dice is: 0.0606	vali mean IoU is: 0.0326
#
# Epoch 18/100
#  ==================================================>	100.00%
# train dice loss is: 0.9761	train mean dice is: 0.0448	train mean IoU is: 0.0237
# vali dice loss is: 0.9688	vali mean dice is: 0.0584	vali mean IoU is: 0.0313
#
# Epoch 19/100
#  ==================================================>	100.00%
# train dice loss is: 0.9753	train mean dice is: 0.0463	train mean IoU is: 0.0245
# vali dice loss is: 0.9672	vali mean dice is: 0.0732	vali mean IoU is: 0.0400
#
# Epoch 20/100
#  ==================================================>	100.00%
# train dice loss is: 0.9744	train mean dice is: 0.0489	train mean IoU is: 0.0259
# vali dice loss is: 0.9669	vali mean dice is: 0.0636	vali mean IoU is: 0.0343
#
# Epoch 21/100
#  ==================================================>	100.00%
# train dice loss is: 0.9730	train mean dice is: 0.0520	train mean IoU is: 0.0277
# vali dice loss is: 0.9633	vali mean dice is: 0.0693	vali mean IoU is: 0.0377
#
# Epoch 22/100
#  ==================================================>	100.00%
# train dice loss is: 0.9715	train mean dice is: 0.0567	train mean IoU is: 0.0303
# vali dice loss is: 0.9626	vali mean dice is: 0.0771	vali mean IoU is: 0.0423
#
# Epoch 23/100
#  ==================================================>	100.00%
# train dice loss is: 0.9700	train mean dice is: 0.0615	train mean IoU is: 0.0331
# vali dice loss is: 0.9588	vali mean dice is: 0.0934	vali mean IoU is: 0.0524
#
# Epoch 24/100
#  ==================================================>	100.00%
# train dice loss is: 0.9675	train mean dice is: 0.0716	train mean IoU is: 0.0391
# vali dice loss is: 0.9566	vali mean dice is: 0.1066	vali mean IoU is: 0.0608
#
# Epoch 25/100
#  ==================================================>	100.00%
# train dice loss is: 0.9637	train mean dice is: 0.0881	train mean IoU is: 0.0491
# vali dice loss is: 0.9462	vali mean dice is: 0.1779	vali mean IoU is: 0.1121
#
# Epoch 26/100
#  ==================================================>	100.00%
# train dice loss is: 0.9581	train mean dice is: 0.1141	train mean IoU is: 0.0655
# vali dice loss is: 0.9462	vali mean dice is: 0.2071	vali mean IoU is: 0.1394
#
# Epoch 27/100
#  ==================================================>	100.00%
# train dice loss is: 0.9527	train mean dice is: 0.1373	train mean IoU is: 0.0824
# vali dice loss is: 0.9311	vali mean dice is: 0.1996	vali mean IoU is: 0.1302
#
# Epoch 28/100
#  ==================================================>	100.00%
# train dice loss is: 0.9464	train mean dice is: 0.1491	train mean IoU is: 0.0920
# vali dice loss is: 0.9212	vali mean dice is: 0.2637	vali mean IoU is: 0.1902
#
# Epoch 29/100
#  ==================================================>	100.00%
# train dice loss is: 0.9341	train mean dice is: 0.1857	train mean IoU is: 0.1219
# vali dice loss is: 0.9500	vali mean dice is: 0.1300	vali mean IoU is: 0.0855
#
# Epoch 30/100
#  ==================================================>	100.00%
# train dice loss is: 0.9138	train mean dice is: 0.2378	train mean IoU is: 0.1663
# vali dice loss is: 0.8950	vali mean dice is: 0.2026	vali mean IoU is: 0.1294
#
# Epoch 31/100
#  ==================================================>	100.00%
# train dice loss is: 0.8852	train mean dice is: 0.2685	train mean IoU is: 0.1956
# vali dice loss is: 0.8394	vali mean dice is: 0.2921	vali mean IoU is: 0.2123
#
# Epoch 32/100
#  ==================================================>	100.00%
# train dice loss is: 0.8409	train mean dice is: 0.3035	train mean IoU is: 0.2294
# vali dice loss is: 0.9745	vali mean dice is: 0.0258	vali mean IoU is: 0.0133
#
# Epoch 33/100
#  ==================================================>	100.00%
# train dice loss is: 0.7891	train mean dice is: 0.3232	train mean IoU is: 0.2478
# vali dice loss is: 0.8720	vali mean dice is: 0.1580	vali mean IoU is: 0.0955
#
# Epoch 34/100
#  ==================================================>	100.00%
# train dice loss is: 0.7408	train mean dice is: 0.3440	train mean IoU is: 0.2702
# vali dice loss is: 0.6971	vali mean dice is: 0.3575	vali mean IoU is: 0.2921
#
# Epoch 35/100
#  ==================================================>	100.00%
# train dice loss is: 0.6931	train mean dice is: 0.3719	train mean IoU is: 0.3024
# vali dice loss is: 0.6474	vali mean dice is: 0.4022	vali mean IoU is: 0.3442
#
# Epoch 36/100
#  ==================================================>	100.00%
# train dice loss is: 0.6682	train mean dice is: 0.3797	train mean IoU is: 0.3119
# vali dice loss is: 0.6386	vali mean dice is: 0.4028	vali mean IoU is: 0.3393
#
# Epoch 37/100
#  ==================================================>	100.00%
# train dice loss is: 0.6462	train mean dice is: 0.3916	train mean IoU is: 0.3269
# vali dice loss is: 0.7107	vali mean dice is: 0.3032	vali mean IoU is: 0.2300
#
# Epoch 38/100
#  ==================================================>	100.00%
# train dice loss is: 0.6310	train mean dice is: 0.3993	train mean IoU is: 0.3379
# vali dice loss is: 0.6069	vali mean dice is: 0.4139	vali mean IoU is: 0.3557
#
# Epoch 39/100
#  ==================================================>	100.00%
# train dice loss is: 0.6194	train mean dice is: 0.4071	train mean IoU is: 0.3469
# vali dice loss is: 0.6767	vali mean dice is: 0.3462	vali mean IoU is: 0.2694
#
# Epoch 40/100
#  ==================================================>	100.00%
# train dice loss is: 0.6078	train mean dice is: 0.4157	train mean IoU is: 0.3576
# vali dice loss is: 0.5990	vali mean dice is: 0.4153	vali mean IoU is: 0.3609
#
# Epoch 41/100
#  ==================================================>	100.00%
# train dice loss is: 0.6021	train mean dice is: 0.4183	train mean IoU is: 0.3629
# vali dice loss is: 0.6183	vali mean dice is: 0.3975	vali mean IoU is: 0.3377
#
# Epoch 42/100
#  ==================================================>	100.00%
# train dice loss is: 0.5990	train mean dice is: 0.4196	train mean IoU is: 0.3648
# vali dice loss is: 0.7170	vali mean dice is: 0.2845	vali mean IoU is: 0.2109
#
# Epoch 43/100
#  ==================================================>	100.00%
# train dice loss is: 0.5914	train mean dice is: 0.4256	train mean IoU is: 0.3724
# vali dice loss is: 0.5834	vali mean dice is: 0.4277	vali mean IoU is: 0.3778
#
# Epoch 44/100
#  ==================================================>	100.00%
# train dice loss is: 0.5867	train mean dice is: 0.4289	train mean IoU is: 0.3780
# vali dice loss is: 0.6006	vali mean dice is: 0.4091	vali mean IoU is: 0.3556
#
# Epoch 45/100
#  ==================================================>	100.00%
# train dice loss is: 0.5817	train mean dice is: 0.4328	train mean IoU is: 0.3821
# vali dice loss is: 0.6359	vali mean dice is: 0.3897	vali mean IoU is: 0.3248
#
# Epoch 46/100
#  ==================================================>	100.00%
# train dice loss is: 0.6867	train mean dice is: 0.3356	train mean IoU is: 0.2670
# vali dice loss is: 0.8627	vali mean dice is: 0.1219	vali mean IoU is: 0.0764
#
# Epoch 47/100
#  ==================================================>	100.00%
# train dice loss is: 0.5990	train mean dice is: 0.4187	train mean IoU is: 0.3627
# vali dice loss is: 0.6090	vali mean dice is: 0.4004	vali mean IoU is: 0.3436
#
# Epoch 48/100
#  ==================================================>	100.00%
# train dice loss is: 0.5898	train mean dice is: 0.4254	train mean IoU is: 0.3716
# vali dice loss is: 0.5969	vali mean dice is: 0.4186	vali mean IoU is: 0.3620
#
# Epoch 49/100
#  ==================================================>	100.00%
# train dice loss is: 0.5803	train mean dice is: 0.4335	train mean IoU is: 0.3836
# vali dice loss is: 0.5811	vali mean dice is: 0.4282	vali mean IoU is: 0.3806
#
# Epoch 50/100
#  ==================================================>	100.00%
# train dice loss is: 0.5754	train mean dice is: 0.4372	train mean IoU is: 0.3884
# vali dice loss is: 0.5745	vali mean dice is: 0.4348	vali mean IoU is: 0.3864
#
# Epoch 51/100
#  ==================================================>	100.00%
# train dice loss is: 0.5734	train mean dice is: 0.4382	train mean IoU is: 0.3899
# vali dice loss is: 0.5947	vali mean dice is: 0.4121	vali mean IoU is: 0.3591
#
# Epoch 52/100
#  ==================================================>	100.00%
# train dice loss is: 0.5682	train mean dice is: 0.4432	train mean IoU is: 0.3971
# vali dice loss is: 0.5751	vali mean dice is: 0.4345	vali mean IoU is: 0.3887
#
# Epoch 53/100
#  ==================================================>	100.00%
# train dice loss is: 0.5716	train mean dice is: 0.4393	train mean IoU is: 0.3929
# vali dice loss is: 0.7317	vali mean dice is: 0.2783	vali mean IoU is: 0.2039
#
# Epoch 54/100
#  ==================================================>	100.00%
# train dice loss is: 0.5656	train mean dice is: 0.4443	train mean IoU is: 0.3991
# vali dice loss is: 0.5782	vali mean dice is: 0.4284	vali mean IoU is: 0.3819
#
# Epoch 55/100
#  ==================================================>	100.00%
# train dice loss is: 0.5615	train mean dice is: 0.4479	train mean IoU is: 0.4041
# vali dice loss is: 0.5961	vali mean dice is: 0.4077	vali mean IoU is: 0.3561
#
# Epoch 56/100
#  ==================================================>	100.00%
# train dice loss is: 0.5630	train mean dice is: 0.4462	train mean IoU is: 0.4022
# vali dice loss is: 0.5774	vali mean dice is: 0.4335	vali mean IoU is: 0.3877
#
# Epoch 57/100
#  ==================================================>	100.00%
# train dice loss is: 0.5587	train mean dice is: 0.4499	train mean IoU is: 0.4074
# vali dice loss is: 0.5945	vali mean dice is: 0.4168	vali mean IoU is: 0.3655
#
# Epoch 58/100
#  ==================================================>	100.00%
# train dice loss is: 0.5578	train mean dice is: 0.4508	train mean IoU is: 0.4085
# vali dice loss is: 0.5705	vali mean dice is: 0.4339	vali mean IoU is: 0.3889
#
# Epoch 59/100
#  ==================================================>	100.00%
# train dice loss is: 0.5547	train mean dice is: 0.4533	train mean IoU is: 0.4124
# vali dice loss is: 0.5729	vali mean dice is: 0.4321	vali mean IoU is: 0.3854
#
# Epoch 60/100
#  ==================================================>	100.00%
# train dice loss is: 0.5529	train mean dice is: 0.4548	train mean IoU is: 0.4148
# vali dice loss is: 0.5944	vali mean dice is: 0.4123	vali mean IoU is: 0.3619
#
# Epoch 61/100
#  ==================================================>	100.00%
# train dice loss is: 0.5520	train mean dice is: 0.4555	train mean IoU is: 0.4158
# vali dice loss is: 0.5681	vali mean dice is: 0.4391	vali mean IoU is: 0.3953
#
# Epoch 62/100
#  ==================================================>	100.00%
# train dice loss is: 0.5512	train mean dice is: 0.4563	train mean IoU is: 0.4169
# vali dice loss is: 0.6396	vali mean dice is: 0.3622	vali mean IoU is: 0.3010
#
# Epoch 63/100
#  ==================================================>	100.00%
# train dice loss is: 0.5494	train mean dice is: 0.4578	train mean IoU is: 0.4193
# vali dice loss is: 0.5661	vali mean dice is: 0.4386	vali mean IoU is: 0.3945
#
# Epoch 64/100
#  ==================================================>	100.00%
# train dice loss is: 0.5490	train mean dice is: 0.4581	train mean IoU is: 0.4197
# vali dice loss is: 0.5986	vali mean dice is: 0.4127	vali mean IoU is: 0.3534
#
# Epoch 65/100
#  ==================================================>	100.00%
# train dice loss is: 0.5467	train mean dice is: 0.4599	train mean IoU is: 0.4226
# vali dice loss is: 0.5806	vali mean dice is: 0.4219	vali mean IoU is: 0.3729
#
# Epoch 66/100
#  ==================================================>	100.00%
# train dice loss is: 0.5460	train mean dice is: 0.4605	train mean IoU is: 0.4236
# vali dice loss is: 0.5743	vali mean dice is: 0.4287	vali mean IoU is: 0.3818
#
# Epoch 67/100
#  ==================================================>	100.00%
# train dice loss is: 0.5452	train mean dice is: 0.4611	train mean IoU is: 0.4247
# vali dice loss is: 0.5857	vali mean dice is: 0.4243	vali mean IoU is: 0.3761
#
# Epoch 68/100
#  ==================================================>	100.00%
# train dice loss is: 0.5450	train mean dice is: 0.4612	train mean IoU is: 0.4246
# vali dice loss is: 0.5677	vali mean dice is: 0.4395	vali mean IoU is: 0.3960
#
# Epoch 69/100
#  ==================================================>	100.00%
# train dice loss is: 0.5427	train mean dice is: 0.4633	train mean IoU is: 0.4281
# vali dice loss is: 0.6383	vali mean dice is: 0.3662	vali mean IoU is: 0.3070
#
# Epoch 70/100
#  ==================================================>	100.00%
# train dice loss is: 0.5455	train mean dice is: 0.4606	train mean IoU is: 0.4238
# vali dice loss is: 0.5986	vali mean dice is: 0.4051	vali mean IoU is: 0.3510
#
# Epoch 71/100
#  ==================================================>	100.00%
# train dice loss is: 0.5476	train mean dice is: 0.4587	train mean IoU is: 0.4214
# vali dice loss is: 0.5714	vali mean dice is: 0.4324	vali mean IoU is: 0.3867
#
# Epoch 72/100
#  ==================================================>	100.00%
# train dice loss is: 0.5415	train mean dice is: 0.4640	train mean IoU is: 0.4293
# vali dice loss is: 0.5675	vali mean dice is: 0.4373	vali mean IoU is: 0.3940
#
# Epoch 73/100
#  ==================================================>	100.00%
# train dice loss is: 0.5412	train mean dice is: 0.4644	train mean IoU is: 0.4299
# vali dice loss is: 0.5855	vali mean dice is: 0.4192	vali mean IoU is: 0.3727
#
# Epoch 74/100
#  ==================================================>	100.00%
# train dice loss is: 0.5404	train mean dice is: 0.4649	train mean IoU is: 0.4308
# vali dice loss is: 0.5981	vali mean dice is: 0.4028	vali mean IoU is: 0.3511
#
# Epoch 75/100
#  ==================================================>	100.00%
# train dice loss is: 0.5393	train mean dice is: 0.4660	train mean IoU is: 0.4328
# vali dice loss is: 0.5967	vali mean dice is: 0.4075	vali mean IoU is: 0.3552
#
# Epoch 76/100
#  ==================================================>	100.00%
# train dice loss is: 0.5398	train mean dice is: 0.4652	train mean IoU is: 0.4314
# vali dice loss is: 0.5764	vali mean dice is: 0.4264	vali mean IoU is: 0.3800
#
# Epoch 77/100
#  ==================================================>	100.00%
# train dice loss is: 0.5389	train mean dice is: 0.4661	train mean IoU is: 0.4328
# vali dice loss is: 0.5653	vali mean dice is: 0.4386	vali mean IoU is: 0.3958
#
# Epoch 78/100
#  ==================================================>	100.00%
# train dice loss is: 0.5397	train mean dice is: 0.4654	train mean IoU is: 0.4317
# vali dice loss is: 0.5870	vali mean dice is: 0.4171	vali mean IoU is: 0.3667
#
# Epoch 79/100
#  ==================================================>	100.00%
# train dice loss is: 0.5391	train mean dice is: 0.4659	train mean IoU is: 0.4325
# vali dice loss is: 0.5657	vali mean dice is: 0.4362	vali mean IoU is: 0.3924
#
# Epoch 80/100
#  ==================================================>	100.00%
# train dice loss is: 0.5386	train mean dice is: 0.4662	train mean IoU is: 0.4330
# vali dice loss is: 0.5682	vali mean dice is: 0.4355	vali mean IoU is: 0.3916
#
# Epoch 81/100
#  ==================================================>	100.00%
# train dice loss is: 0.5376	train mean dice is: 0.4671	train mean IoU is: 0.4344
# vali dice loss is: 0.5871	vali mean dice is: 0.4147	vali mean IoU is: 0.3630
#
# Epoch 82/100
#  ==================================================>	100.00%
# train dice loss is: 0.5372	train mean dice is: 0.4673	train mean IoU is: 0.4348
# vali dice loss is: 0.5638	vali mean dice is: 0.4386	vali mean IoU is: 0.3962
#
# Epoch 83/100
#  ==================================================>	100.00%
# train dice loss is: 0.5374	train mean dice is: 0.4670	train mean IoU is: 0.4343
# vali dice loss is: 0.5654	vali mean dice is: 0.4365	vali mean IoU is: 0.3924
#
# Epoch 84/100
#  ==================================================>	100.00%
# train dice loss is: 0.5355	train mean dice is: 0.4688	train mean IoU is: 0.4374
# vali dice loss is: 0.5610	vali mean dice is: 0.4418	vali mean IoU is: 0.3987
#
# Epoch 85/100
#  ==================================================>	100.00%
# train dice loss is: 0.5360	train mean dice is: 0.4683	train mean IoU is: 0.4366
# vali dice loss is: 0.5662	vali mean dice is: 0.4353	vali mean IoU is: 0.3905
#
# Epoch 86/100
#  ==================================================>	100.00%
# train dice loss is: 0.5351	train mean dice is: 0.4690	train mean IoU is: 0.4377
# vali dice loss is: 0.5623	vali mean dice is: 0.4415	vali mean IoU is: 0.3993
#
# Epoch 87/100
#  ==================================================>	100.00%
# train dice loss is: 0.5348	train mean dice is: 0.4694	train mean IoU is: 0.4383
# vali dice loss is: 0.5656	vali mean dice is: 0.4360	vali mean IoU is: 0.3923
#
# Epoch 88/100
#  ==================================================>	100.00%
# train dice loss is: 0.5344	train mean dice is: 0.4699	train mean IoU is: 0.4392
# vali dice loss is: 0.5671	vali mean dice is: 0.4366	vali mean IoU is: 0.3932
#
# Epoch 89/100
#  ==================================================>	100.00%
# train dice loss is: 0.5345	train mean dice is: 0.4696	train mean IoU is: 0.4385
# vali dice loss is: 0.5638	vali mean dice is: 0.4379	vali mean IoU is: 0.3938
#
# Epoch 90/100
#  ==================================================>	100.00%
# train dice loss is: 0.5335	train mean dice is: 0.4705	train mean IoU is: 0.4401
# vali dice loss is: 0.5638	vali mean dice is: 0.4400	vali mean IoU is: 0.3964
#
# Epoch 91/100
#  ==================================================>	100.00%
# train dice loss is: 0.5329	train mean dice is: 0.4708	train mean IoU is: 0.4407
# vali dice loss is: 0.6141	vali mean dice is: 0.3917	vali mean IoU is: 0.3343
#
# Epoch 92/100
#  ==================================================>	100.00%
# train dice loss is: 0.5331	train mean dice is: 0.4709	train mean IoU is: 0.4410
# vali dice loss is: 0.5718	vali mean dice is: 0.4301	vali mean IoU is: 0.3851
#
# Epoch 93/100
#  ==================================================>	100.00%
# train dice loss is: 0.5325	train mean dice is: 0.4713	train mean IoU is: 0.4415
# vali dice loss is: 0.5643	vali mean dice is: 0.4389	vali mean IoU is: 0.3958
#
# Epoch 94/100
#  ==================================================>	100.00%
# train dice loss is: 0.5322	train mean dice is: 0.4716	train mean IoU is: 0.4421
# vali dice loss is: 0.5644	vali mean dice is: 0.4387	vali mean IoU is: 0.3953
#
# Epoch 95/100
#  ==================================================>	100.00%
# train dice loss is: 0.5328	train mean dice is: 0.4711	train mean IoU is: 0.4414
# vali dice loss is: 0.5652	vali mean dice is: 0.4363	vali mean IoU is: 0.3924
#
# Epoch 96/100
#  ==================================================>	100.00%
# train dice loss is: 0.5323	train mean dice is: 0.4713	train mean IoU is: 0.4416
# vali dice loss is: 0.5696	vali mean dice is: 0.4308	vali mean IoU is: 0.3860
#
# Epoch 97/100
#  ==================================================>	100.00%
# train dice loss is: 0.5325	train mean dice is: 0.4711	train mean IoU is: 0.4412
# vali dice loss is: 0.5628	vali mean dice is: 0.4413	vali mean IoU is: 0.3984
#
# Epoch 98/100
#  ==================================================>	100.00%
# train dice loss is: 0.5319	train mean dice is: 0.4717	train mean IoU is: 0.4423
# vali dice loss is: 0.5790	vali mean dice is: 0.4211	vali mean IoU is: 0.3752
#
# Epoch 99/100
#  ==================================================>	100.00%
# train dice loss is: 0.5316	train mean dice is: 0.4719	train mean IoU is: 0.4425
# vali dice loss is: 0.5734	vali mean dice is: 0.4280	vali mean IoU is: 0.3827
#
# Epoch 100/100
#  ==================================================>	100.00%
# train dice loss is: 0.5316	train mean dice is: 0.4719	train mean IoU is: 0.4425
# vali dice loss is: 0.5635	vali mean dice is: 0.4403	vali mean IoU is: 0.3980
#
# Costs 4983.644648075104s.

# %%
plt.figure()
x = range(1, true_epoch+1)
# print(true_epoch)
loss1, loss2 = train_loss_list, vali_loss_list
# print(loss1)
plt.title(f'train loss vs vali loss, epoch={true_epoch}, learning rate={learning_rate}, optimizer=SGD')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.plot(x, loss1, label='train loss')
plt.plot(x, loss2, label='vali loss')
plt.legend()
plt.savefig('./SGD_0.01/loss_plot.png')
plt.show()

# %%
plt.figure()
x = range(1, true_epoch+1)
# print(true_epoch)
loss1, loss2 = train_dice_list, vali_dice_list
# print(loss1)
plt.title(f'train dice vs vali dice, epoch={true_epoch}, learning rate={learning_rate}, optimizer=SGD')
plt.xlabel('epoch')
plt.ylabel('dice score')
plt.plot(x, loss1, label='train dice')
plt.plot(x, loss2, label='vali dice')
plt.legend()
plt.savefig('./SGD_0.01/dice_plot.png')
plt.show()

# %%
plt.figure()
x = range(1, true_epoch+1)
# print(true_epoch)
loss1, loss2 = train_iou_list, vali_iou_list
# print(loss1)
plt.title(f'train IoU vs vali IoU, epoch={true_epoch}, learning rate={learning_rate}, optimizer=SGD')
plt.xlabel('epoch')
plt.ylabel('IoU')
plt.plot(x, loss1, label='train IoU')
plt.plot(x, loss2, label='vali IoU')
plt.legend()
plt.savefig('./SGD_0.01/IoU_plot.png')
plt.show()

# %%
import os
class TestKit19Set(Dataset):
    def __init__(self, datapath, new_size, augmentation=None, preprocessing=None):
        self.datapath = datapath
        self.new_size = new_size
        self.augmentation = augmentation
        self.preprocessing = preprocessing

    def __getitem__(self, i):
        input_img_path = self.datapath+f"/case_{i+210:05d}/imaging.nii.gz"
        # input_seg_path = self.datapath+f"/case_{i:05d}/segmentation.nii.gz"

        input_image = sitk.ReadImage(input_img_path)
        # print(type(input_image))

        # Get the current spacing and size of the input image
        input_spacing = input_image.GetSpacing()
        input_size = input_image.GetSize()

        # Compute the desired spacing based on the new size
        new_spacing = [old_sz * old_spc / new_sz for old_sz, old_spc, new_sz in
                       zip(input_size, input_spacing, self.new_size)]

        # Create the resampling transformation
        resampler = sitk.ResampleImageFilter()
        resampler.SetSize(self.new_size)
        resampler.SetOutputSpacing(new_spacing)
        resampler.SetOutputOrigin(input_image.GetOrigin())
        resampler.SetOutputDirection(input_image.GetDirection())

        # Perform the resampling
        output_image = resampler.Execute(input_image)
        # folder_path = f"/test_visual/case_{i + 210:05d}"
        # if not os.path.exists(folder_path):
            # os.makedirs(folder_path)
        output_filename = f"./test_visual/case_{i + 210:05d}/imaging.nii.gz"
        sitk.WriteImage(output_image, output_filename)
        output_image = sitk.GetArrayFromImage(output_image)
        output_image = output_image.astype(np.float32)
        output_image = np.transpose(output_image, (2, 1, 0))

        return output_image
        # return output_image, output_mask

    def __len__(self):
        return int(90)

# %%
test_set = TestKit19Set("data", new_size=[64, 256, 256])
test_loader = DataLoader(test_set, batch_size=1, shuffle=False)

# %%
device = torch.device("cuda")
model = UNet3D()
model.load_state_dict(torch.load("./work/new_best_model_3.pth"))

model.to(device)

from tqdm.notebook import tqdm_notebook
torch.cuda.empty_cache()
tqdm_notebook.monitor_interval = 0
for i, img in tqdm_notebook(enumerate(test_loader),desc="Batch progress", leave=False):
    with torch.no_grad():
        img = img.unsqueeze(1).to(device)
        # print(img.shape)
        out = model(img)
        # print(out.shape)
        out = torch.squeeze(out)
        out = out.permute(0,3,1,2)
        # print(out.shape)
        # print(out.shape)
        # print(out[0,24,24,24], out[1,24,24,24],out[2,24,24,24])
        # print(out[0, 36, 36, 36], out[1, 36, 36, 36], out[2, 36, 36, 36])
        # the output shape is [3, 64, 128,128]

        out = torch.argmax(out, dim=0)
        # the shape will be [64,128,128]
        # print(out.shape)
        # is_all_zero = torch.all(out == 0)
        # print("Is the tensor all zero?", is_all_zero)
        # print(out.shape)
        # unique = np.unique(out)
        # print(len(unique))
        
        out = out.cpu()
        out = out.detach().numpy()
        out = np.transpose(out, (2, 1, 0))
        # unique = np.unique(out)
        # print(out.shape)
        out = sitk.GetImageFromArray(out)
        # print(out.GetSize(), type(out))
        output_filename = f"./test_visual/case_{i+210:05d}/segmentation.nii.gz"
        # print(output_filename)
        sitk.WriteImage(out, output_filename)
# Out:
# Batch progress: 0it [00:00, ?it/s]
