# %%
import torch.cuda as cuda

# 检查CUDA是否可用并获取GPU数量
device_count = cuda.device_count()
print(f"Number of available GPUs: {device_count}")

# 获取每个GPU的名称
for i in range(device_count):
    device_name = cuda.get_device_name(i)
    print(f"GPU {i+1}: {device_name}")

# 获取每个GPU的显存容量
for i in range(device_count):
    device_properties = cuda.get_device_properties(i)
    print(f"GPU {i+1} Memory: {device_properties.total_memory / 1024 / 1024} MB")
# Out:
# Number of available GPUs: 4
# GPU 1: NVIDIA GeForce RTX 4090
# GPU 2: NVIDIA GeForce RTX 4090
# GPU 3: NVIDIA GeForce RTX 4090
# GPU 4: NVIDIA GeForce RTX 4090
# GPU 1 Memory: 24217.3125 MB
# GPU 2 Memory: 24217.3125 MB
# GPU 3 Memory: 24217.3125 MB
# GPU 4 Memory: 24217.3125 MB

# %%
import numpy as np
import torch.nn as nn
import torch.optim as optim
# from torch.utils.data import Dataset, DataLoader
from monai.data import DataLoader, Dataset

import sys
# import itk

import SimpleITK as sitk
import time

import torch
# import segmentation_models_pytorch as smp
from torch.nn.functional import one_hot

from tqdm import tqdm
import matplotlib.pyplot as plt
# Out:
# 2023-08-17 02:22:54.770561: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-17 02:22:56.635346: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
class Kit19Set(Dataset):
    def __init__(self, datapath, new_size, augmentation=None, preprocessing=None):
        self.datapath = datapath
        self.new_size = new_size
        self.augmentation = augmentation
        self.preprocessing = preprocessing

    def __getitem__(self, i):
        input_img_path = self.datapath+f"/case_{i:05d}/imaging.nii.gz"
        input_seg_path = self.datapath+f"/case_{i:05d}/segmentation.nii.gz"

        input_image = sitk.ReadImage(input_img_path)
        output_image = sitk.GetArrayFromImage(input_image)
        output_image = output_image.astype(np.float32)
        output_image = np.transpose(output_image, (2, 1, 0))
        output_image = torch.tensor(output_image)

        input_mask = sitk.ReadImage(input_seg_path)
        output_mask = sitk.GetArrayFromImage(input_mask)
        output_mask = output_mask.astype(np.float32)
        output_mask = np.transpose(output_mask, (2, 1, 0))
        output_mask = torch.tensor(output_mask)
        output_mask = one_hot(output_mask.long(), 3)
        output_mask = output_mask.permute(3, 1, 2, 0)


        if self.augmentation:
            sample = self.augmentation(image=output_image, mask=output_mask)
            output_image, output_mask = sample['image'], sample['mask']

        if self.preprocessing:
            sample = self.preprocessing(image=output_image, mask=output_mask)
            output_image, output_mask = sample['image'], sample['mask']

        return output_image, output_mask

    def __len__(self):
        return int(210)

# %%
new_size = [64, 128, 128]

dataset = Kit19Set("/home/featurize/data/resized_data_64_128", new_size=new_size)
train_size = int(0.8 * len(dataset))
vali_size = len(dataset) - train_size

# Use seed at 0 for reproducibility
torch.manual_seed(0)
train_dataset, vali_dataset = torch.utils.data.random_split(dataset, [train_size, vali_size])

train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True, num_workers=12)
vali_loader = DataLoader(vali_dataset, batch_size=4, shuffle=True, num_workers=12)
# dataloader = DataLoader(dataset=dataset, shuffle=False, batch_size=4)

# %%
import torch.nn.functional as F
class UNet3D(nn.Module):
    def __init__(self, in_channels=1, out_channels=3, level_channels=[64, 128, 256], bottleneck_channel=512):
        super(UNet3D, self).__init__()

        self.maxpool3d = nn.MaxPool3d(kernel_size=2, stride=2)

        # Encoder part
        self.encoder1 = self._make_encoder_block(in_channels, level_channels[0])
        self.encoder2 = self._make_encoder_block(level_channels[0], level_channels[1])
        self.encoder3 = self._make_encoder_block(level_channels[1], level_channels[2])

        # Bottleneck part
        self.bottleneck = self._make_encoder_block(level_channels[2], bottleneck_channel)

        # Decoder part
        self.upconv3 = nn.ConvTranspose3d(bottleneck_channel, bottleneck_channel, kernel_size=2, stride=2)
        self.act = nn.ReLU(inplace=True)
        self.decoder3 = self._make_decoder_block(level_channels[2]+bottleneck_channel, level_channels[2])

        self.upconv2 = nn.ConvTranspose3d(level_channels[2], level_channels[2], kernel_size=2, stride=2)
        self.decoder2 = self._make_decoder_block(level_channels[1]+level_channels[2], level_channels[1])

        self.upconv1 = nn.ConvTranspose3d(level_channels[1], level_channels[1], kernel_size=2, stride=2)
        self.decoder1 = self._make_decoder_block(level_channels[0]+level_channels[1], level_channels[0])

        # Out layer conv
        self.outlayer = nn.Conv3d(in_channels=level_channels[0], out_channels=out_channels, kernel_size=1)
        self.soft = nn.Softmax(dim=0)

    def forward(self, x):

        # Encode part
        res1 = self.encoder1(x)
        x = self.maxpool3d(res1)

        res2 = self.encoder2(x)
        x = self.maxpool3d(res2)

        res3 = self.encoder3(x)
        x = self.maxpool3d(res3)

        # Bottleneck part
        x = self.bottleneck(x)
        # x = self.act(x)

        # Decode part
        x = self.upconv3(x)
        x = torch.cat((res3, x), dim=1)
        x = self.decoder3(x)

        x = self.upconv2(x)
        x = torch.cat((res2, x), dim=1)
        x = self.decoder2(x)

        x = self.upconv1(x)
        x = torch.cat((res1, x), dim=1)
        x = self.decoder1(x)

        # Out layer
        out = self.outlayer(x)
        # print(out.shape)
        # out = self.soft(x)
        out = F.softmax(out, dim=1)
        out = out.permute(0,1,3,4,2)
        # print(out.shape)

        return out

    def _make_encoder_block(self, in_channels, out_channels):
        return nn.Sequential(
            nn.Conv3d(in_channels, out_channels//2, kernel_size=3, padding=1),
            nn.BatchNorm3d(out_channels//2),
            nn.ReLU(inplace=True),
            nn.Conv3d(out_channels//2, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm3d(out_channels),
            nn.ReLU(inplace=True)
        )

    def _make_decoder_block(self, in_channels, out_channels):
        return nn.Sequential(
            nn.Conv3d(in_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm3d(out_channels),
            nn.ReLU(inplace=True),
            nn.Conv3d(out_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm3d(out_channels),
            nn.ReLU(inplace=True)
        )

# %%
from monai.losses import DiceLoss
from monai.metrics import DiceMetric
from monai.metrics import MeanIoU
from monai.metrics import ConfusionMatrixMetric
from monai.metrics import get_confusion_matrix, compute_confusion_matrix_metric
# from monai.metrics import compute_meaniou
torch.cuda.set_device(0)
device = torch.device("cuda")
model = UNet3D()
# if device_count > 1:
#     model = nn.DataParallel(model)
#     print(f"Use {device_count} GPUs to train.")

model.to(device)

loss_function = DiceLoss(include_background=False).to(device)

train_dice_metric = DiceMetric(include_background=False, reduction="mean")
vali_dice_metric = DiceMetric(include_background=False, reduction="mean")

train_mean_iou_metric = MeanIoU(include_background=False, reduction="mean")
vali_mean_iou_metric = MeanIoU(include_background=False, reduction="mean")

# train_conf_matrix = ConfusionMatrixMetric(include_background=False, reduction="mean")


# loss_function = nn.CrossEntropyLoss()

# %%
learning_rate = 0.01
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
torch.cuda.empty_cache()
allocated_memory = torch.cuda.memory_allocated()
print(f"Allocated Memory: {allocated_memory / 1024 / 1024} MB")
cached_memory = torch.cuda.memory_cached()
print(f"Cached Memory: {cached_memory / 1024 / 1024} MB")
# Out:
# Allocated Memory: 73.96484375 MB
# Cached Memory: 102.0 MB

# %%
torch.cuda.empty_cache()
# torch.autograd.set_detect_anomaly(True)
start = time.time()
best_loss = float('inf')
train_loss_list, vali_loss_list = [], []
train_dice_list, vali_dice_list = [], []
train_iou_list, vali_iou_list = [], []
epoch = 100
true_epoch = 0
for e in range(epoch):
    model.train()

    train_loss = 0.0
    cm_list = []
    # iou = 0
    train_dice_metric.reset()
    train_mean_iou_metric.reset()
    per = 0
    tqdm.write(f"Epoch {e+1}/{epoch}")
    for img, mask in train_loader:
        torch.cuda.empty_cache()
        img = img.unsqueeze(1).to(device)
        # print(img.shape)
        # mask = mask.unsqueeze(1).to(device)
        mask = mask.to(device)
        # print(f"mask shape:{mask.shape}")
        
        optimizer.zero_grad()

        out = model(img)
        # out = out.permute(0,1,3,4,2)
        # out = torch.argmax(out, dim=1)
        # print(out.shape, mask.shape)
        # print(torch.all(out == 0))
        # print((np.unique(out.cpu())))
        # print(f"out shape:{out.shape}")

        # print("forward success.")

        loss = loss_function(out, mask)
        train_loss += loss.item()
        train_dice_metric((out>0.5).float(), mask)
        train_mean_iou_metric((out>0.5).float(), mask)
        # cm = get_confusion_matrix((out>0.5).float(), mask, include_background=False)
        # cm_list.append(cm.cpu())
        
        # meaniou = compute_meaniou((out>0.5).float(), mask, include_background=False)
        # iou += meaniou.sum().item()

        
        loss.backward()
        optimizer.step()
        
        per += 1
        percentage = per/len(train_loader)
        now = '='*int(percentage*50)+'>'
        left = '*'*int((1-percentage)*50)
        percen = format(percentage*100, '.2f')
        print("\r", now + left + '\t' + f"{percen}" + '%', end="", flush=True)

        # print("optimize success.")
    epoch_loss = train_loss / len(train_loader)
    train_mean_dice = train_dice_metric.aggregate().item()
    train_mean_iou = train_mean_iou_metric.aggregate().item()
    # tqdm.write(f"Train Loss: {epoch_loss}")
    train_loss_list.append(epoch_loss)
    train_dice_list.append(train_mean_dice)
    train_iou_list.append(train_mean_iou)
    print("\ntrain dice loss is: " + f"{epoch_loss:.4f}\t" + "train mean dice is: " + f"{train_mean_dice:.4f}\t" 
          + "train mean IoU is: " + f"{train_mean_iou:.4f}")
    # cm_array = np.vstack(cm_list)
    # print(cm_array.shape)
    # total_cm = np.sum(cm_array, axis=0)
    # print(total_cm.shape)
    # total_cm = np.sum(cm_array, axis=0)
    # print(total_cm.shape)
    
    
    
    model.eval()
    eval_loss = 0.0
    vali_dice_metric.reset()
    vali_mean_iou_metric.reset()
    with torch.no_grad():
        for img, mask in vali_loader:
            torch.cuda.empty_cache()
            img = img.unsqueeze(1).to(device)
            # print(img.shape)
            # mask = mask.unsqueeze(1).to(device)
            mask = mask.to(device)

            out = model(img)
            # out = out.permute(0,1,3,4,2)

            loss = loss_function(out, mask)
            eval_loss += loss.item()
            vali_dice_metric((out>0.5).float(), mask)
            vali_mean_iou_metric((out>0.5).float(), mask)
    vali_loss = eval_loss / len(vali_loader)
    vali_mean_dice = vali_dice_metric.aggregate().item()
    vali_mean_iou = vali_mean_iou_metric.aggregate().item()
    # tqdm.write(f"Validation Loss: {vali_loss}")
    vali_loss_list.append(vali_loss)
    vali_dice_list.append(vali_mean_dice)
    vali_iou_list.append(vali_mean_iou)
    
    print(f"vali dice loss is: " + f"{vali_loss:.4f}\t" + "vali mean dice is: " + f"{vali_mean_dice:.4f}\t" 
          + "vali mean IoU is: " + f"{vali_mean_iou:.4f}\n")
    
    if vali_loss < best_loss:
        best_loss = vali_loss
        torch.save(model.state_dict(), "./Adam_0.01/best_model.pth")
    
    true_epoch += 1

end = time.time()
print(f"Costs {end-start}s.")
# Out:
# Epoch 1/100
#  ==================================================>	100.00%
# train dice loss is: 0.9338	train mean dice is: 0.0705	train mean IoU is: 0.0393
# vali dice loss is: 0.9430	vali mean dice is: 0.0561	vali mean IoU is: 0.0298
#
# Epoch 2/100
#  ==================================================>	100.00%
# train dice loss is: 0.8450	train mean dice is: 0.1580	train mean IoU is: 0.0953
# vali dice loss is: 0.9988	vali mean dice is: 0.0010	vali mean IoU is: 0.0005
#
# Epoch 3/100
#  ==================================================>	100.00%
# train dice loss is: 0.7459	train mean dice is: 0.2559	train mean IoU is: 0.1693
# vali dice loss is: 0.8365	vali mean dice is: 0.1634	vali mean IoU is: 0.0980
#
# Epoch 4/100
#  ==================================================>	100.00%
# train dice loss is: 0.6966	train mean dice is: 0.3052	train mean IoU is: 0.2133
# vali dice loss is: 1.0000	vali mean dice is: 0.0000	vali mean IoU is: 0.0000
#
# Epoch 5/100
#  ==================================================>	100.00%
# train dice loss is: 0.6713	train mean dice is: 0.3308	train mean IoU is: 0.2377
# vali dice loss is: 0.6833	vali mean dice is: 0.3166	vali mean IoU is: 0.2296
#
# Epoch 6/100
#  ==================================================>	100.00%
# train dice loss is: 0.6459	train mean dice is: 0.3552	train mean IoU is: 0.2637
# vali dice loss is: 0.9997	vali mean dice is: 0.0003	vali mean IoU is: 0.0002
#
# Epoch 7/100
#  ==================================================>	100.00%
# train dice loss is: 0.6218	train mean dice is: 0.3791	train mean IoU is: 0.2896
# vali dice loss is: 0.8749	vali mean dice is: 0.1214	vali mean IoU is: 0.0790
#
# Epoch 8/100
#  ==================================================>	100.00%
# train dice loss is: 0.6119	train mean dice is: 0.3889	train mean IoU is: 0.3014
# vali dice loss is: 0.7208	vali mean dice is: 0.2849	vali mean IoU is: 0.2036
#
# Epoch 9/100
#  ==================================================>	100.00%
# train dice loss is: 0.5993	train mean dice is: 0.4012	train mean IoU is: 0.3138
# vali dice loss is: 0.6831	vali mean dice is: 0.3183	vali mean IoU is: 0.2375
#
# Epoch 10/100
#  ==================================================>	100.00%
# train dice loss is: 0.5896	train mean dice is: 0.4109	train mean IoU is: 0.3257
# vali dice loss is: 0.5962	vali mean dice is: 0.4022	vali mean IoU is: 0.3186
#
# Epoch 11/100
#  ==================================================>	100.00%
# train dice loss is: 0.5829	train mean dice is: 0.4175	train mean IoU is: 0.3324
# vali dice loss is: 0.9083	vali mean dice is: 0.0917	vali mean IoU is: 0.0528
#
# Epoch 12/100
#  ==================================================>	100.00%
# train dice loss is: 0.5734	train mean dice is: 0.4270	train mean IoU is: 0.3410
# vali dice loss is: 0.6784	vali mean dice is: 0.3241	vali mean IoU is: 0.2373
#
# Epoch 13/100
#  ==================================================>	100.00%
# train dice loss is: 0.5646	train mean dice is: 0.4357	train mean IoU is: 0.3526
# vali dice loss is: 0.6315	vali mean dice is: 0.3683	vali mean IoU is: 0.2894
#
# Epoch 14/100
#  ==================================================>	100.00%
# train dice loss is: 0.5594	train mean dice is: 0.4409	train mean IoU is: 0.3569
# vali dice loss is: 0.6672	vali mean dice is: 0.3329	vali mean IoU is: 0.2460
#
# Epoch 15/100
#  ==================================================>	100.00%
# train dice loss is: 0.5612	train mean dice is: 0.4391	train mean IoU is: 0.3535
# vali dice loss is: 0.6152	vali mean dice is: 0.3852	vali mean IoU is: 0.2997
#
# Epoch 16/100
#  ==================================================>	100.00%
# train dice loss is: 0.5619	train mean dice is: 0.4383	train mean IoU is: 0.3537
# vali dice loss is: 0.6097	vali mean dice is: 0.3860	vali mean IoU is: 0.3083
#
# Epoch 17/100
#  ==================================================>	100.00%
# train dice loss is: 0.5410	train mean dice is: 0.4592	train mean IoU is: 0.3751
# vali dice loss is: 0.6096	vali mean dice is: 0.3899	vali mean IoU is: 0.3138
#
# Epoch 18/100
#  ==================================================>	100.00%
# train dice loss is: 0.5471	train mean dice is: 0.4533	train mean IoU is: 0.3670
# vali dice loss is: 0.6131	vali mean dice is: 0.3853	vali mean IoU is: 0.3082
#
# Epoch 19/100
#  ==================================================>	100.00%
# train dice loss is: 0.5296	train mean dice is: 0.4707	train mean IoU is: 0.3829
# vali dice loss is: 0.7524	vali mean dice is: 0.2477	vali mean IoU is: 0.1690
#
# Epoch 20/100
#  ==================================================>	100.00%
# train dice loss is: 0.5134	train mean dice is: 0.4871	train mean IoU is: 0.3925
# vali dice loss is: 0.5507	vali mean dice is: 0.4497	vali mean IoU is: 0.3719
#
# Epoch 21/100
#  ==================================================>	100.00%
# train dice loss is: 0.5153	train mean dice is: 0.4849	train mean IoU is: 0.3898
# vali dice loss is: 0.5856	vali mean dice is: 0.4158	vali mean IoU is: 0.3484
#
# Epoch 22/100
#  ==================================================>	100.00%
# train dice loss is: 0.4936	train mean dice is: 0.5069	train mean IoU is: 0.4109
# vali dice loss is: 0.7828	vali mean dice is: 0.2182	vali mean IoU is: 0.1462
#
# Epoch 23/100
#  ==================================================>	100.00%
# train dice loss is: 0.4931	train mean dice is: 0.5072	train mean IoU is: 0.4105
# vali dice loss is: 0.5560	vali mean dice is: 0.4458	vali mean IoU is: 0.3673
#
# Epoch 24/100
#  ==================================================>	100.00%
# train dice loss is: 0.4778	train mean dice is: 0.5226	train mean IoU is: 0.4271
# vali dice loss is: 0.5776	vali mean dice is: 0.4230	vali mean IoU is: 0.3496
#
# Epoch 25/100
#  ==================================================>	100.00%
# train dice loss is: 0.4623	train mean dice is: 0.5379	train mean IoU is: 0.4417
# vali dice loss is: 0.7951	vali mean dice is: 0.2040	vali mean IoU is: 0.1392
#
# Epoch 26/100
#  ==================================================>	100.00%
# train dice loss is: 0.4594	train mean dice is: 0.5409	train mean IoU is: 0.4428
# vali dice loss is: 0.6014	vali mean dice is: 0.4072	vali mean IoU is: 0.3358
#
# Epoch 27/100
#  ==================================================>	100.00%
# train dice loss is: 0.4329	train mean dice is: 0.5674	train mean IoU is: 0.4716
# vali dice loss is: 0.5188	vali mean dice is: 0.4828	vali mean IoU is: 0.4010
#
# Epoch 28/100
#  ==================================================>	100.00%
# train dice loss is: 0.4338	train mean dice is: 0.5665	train mean IoU is: 0.4664
# vali dice loss is: 0.5902	vali mean dice is: 0.4117	vali mean IoU is: 0.3401
#
# Epoch 29/100
#  ==================================================>	100.00%
# train dice loss is: 0.4122	train mean dice is: 0.5881	train mean IoU is: 0.4900
# vali dice loss is: 0.5480	vali mean dice is: 0.4520	vali mean IoU is: 0.3606
#
# Epoch 30/100
#  ==================================================>	100.00%
# train dice loss is: 0.3989	train mean dice is: 0.6015	train mean IoU is: 0.5014
# vali dice loss is: 0.5373	vali mean dice is: 0.4604	vali mean IoU is: 0.3673
#
# Epoch 31/100
#  ==================================================>	100.00%
# train dice loss is: 0.3963	train mean dice is: 0.6042	train mean IoU is: 0.5053
# vali dice loss is: 0.4924	vali mean dice is: 0.5074	vali mean IoU is: 0.4266
#
# Epoch 32/100
#  ==================================================>	100.00%
# train dice loss is: 0.4055	train mean dice is: 0.5950	train mean IoU is: 0.4931
# vali dice loss is: 0.5608	vali mean dice is: 0.4384	vali mean IoU is: 0.3436
#
# Epoch 33/100
#  ==================================================>	100.00%
# train dice loss is: 0.3840	train mean dice is: 0.6165	train mean IoU is: 0.5153
# vali dice loss is: 0.5114	vali mean dice is: 0.4836	vali mean IoU is: 0.4021
#
# Epoch 34/100
#  ==================================================>	100.00%
# train dice loss is: 0.3706	train mean dice is: 0.6297	train mean IoU is: 0.5308
# vali dice loss is: 0.5067	vali mean dice is: 0.4949	vali mean IoU is: 0.4071
#
# Epoch 35/100
#  ==================================================>	100.00%
# train dice loss is: 0.3744	train mean dice is: 0.6259	train mean IoU is: 0.5257
# vali dice loss is: 0.5000	vali mean dice is: 0.4994	vali mean IoU is: 0.4120
#
# Epoch 36/100
#  ==================================================>	100.00%
# train dice loss is: 0.3678	train mean dice is: 0.6325	train mean IoU is: 0.5338
# vali dice loss is: 0.5096	vali mean dice is: 0.4793	vali mean IoU is: 0.3867
#
# Epoch 37/100
#  ==================================================>	100.00%
# train dice loss is: 0.3668	train mean dice is: 0.6336	train mean IoU is: 0.5350
# vali dice loss is: 0.4752	vali mean dice is: 0.5202	vali mean IoU is: 0.4348
#
# Epoch 38/100
#  ==================================================>	100.00%
# train dice loss is: 0.3484	train mean dice is: 0.6521	train mean IoU is: 0.5527
# vali dice loss is: 0.4990	vali mean dice is: 0.5016	vali mean IoU is: 0.4285
#
# Epoch 39/100
#  ==================================================>	100.00%
# train dice loss is: 0.3587	train mean dice is: 0.6418	train mean IoU is: 0.5430
# vali dice loss is: 0.4851	vali mean dice is: 0.5129	vali mean IoU is: 0.4377
#
# Epoch 40/100
#  ==================================================>	100.00%
# train dice loss is: 0.3521	train mean dice is: 0.6483	train mean IoU is: 0.5507
# vali dice loss is: 0.4789	vali mean dice is: 0.5201	vali mean IoU is: 0.4429
#
# Epoch 41/100
#  ==================================================>	100.00%
# train dice loss is: 0.3265	train mean dice is: 0.6740	train mean IoU is: 0.5760
# vali dice loss is: 0.4651	vali mean dice is: 0.5271	vali mean IoU is: 0.4492
#
# Epoch 42/100
#  ==================================================>	100.00%
# train dice loss is: 0.3260	train mean dice is: 0.6747	train mean IoU is: 0.5768
# vali dice loss is: 0.4943	vali mean dice is: 0.5076	vali mean IoU is: 0.4376
#
# Epoch 43/100
#  ==================================================>	100.00%
# train dice loss is: 0.3323	train mean dice is: 0.6680	train mean IoU is: 0.5694
# vali dice loss is: 0.4959	vali mean dice is: 0.4981	vali mean IoU is: 0.4208
#
# Epoch 44/100
#  ==================================================>	100.00%
# train dice loss is: 0.3278	train mean dice is: 0.6725	train mean IoU is: 0.5734
# vali dice loss is: 0.6231	vali mean dice is: 0.3765	vali mean IoU is: 0.2814
#
# Epoch 45/100
#  ==================================================>	100.00%
# train dice loss is: 0.3591	train mean dice is: 0.6414	train mean IoU is: 0.5415
# vali dice loss is: 0.5366	vali mean dice is: 0.4561	vali mean IoU is: 0.3687
#
# Epoch 46/100
#  ==================================================>	100.00%
# train dice loss is: 0.3182	train mean dice is: 0.6824	train mean IoU is: 0.5826
# vali dice loss is: 0.4731	vali mean dice is: 0.5323	vali mean IoU is: 0.4462
#
# Epoch 47/100
#  ==================================================>	100.00%
# train dice loss is: 0.3117	train mean dice is: 0.6888	train mean IoU is: 0.5912
# vali dice loss is: 0.4936	vali mean dice is: 0.5024	vali mean IoU is: 0.4121
#
# Epoch 48/100
#  ==================================================>	100.00%
# train dice loss is: 0.3012	train mean dice is: 0.6992	train mean IoU is: 0.6017
# vali dice loss is: 0.4781	vali mean dice is: 0.5211	vali mean IoU is: 0.4472
#
# Epoch 49/100
#  ==================================================>	100.00%
# train dice loss is: 0.2882	train mean dice is: 0.7124	train mean IoU is: 0.6174
# vali dice loss is: 0.4769	vali mean dice is: 0.5261	vali mean IoU is: 0.4361
#
# Epoch 50/100
#  ==================================================>	100.00%
# train dice loss is: 0.3067	train mean dice is: 0.6936	train mean IoU is: 0.5991
# vali dice loss is: 0.4822	vali mean dice is: 0.5193	vali mean IoU is: 0.4387
#
# Epoch 51/100
#  ==================================================>	100.00%
# train dice loss is: 0.2852	train mean dice is: 0.7153	train mean IoU is: 0.6184
# vali dice loss is: 0.4554	vali mean dice is: 0.5411	vali mean IoU is: 0.4611
#
# Epoch 52/100
#  ==================================================>	100.00%
# train dice loss is: 0.2755	train mean dice is: 0.7252	train mean IoU is: 0.6306
# vali dice loss is: 0.4857	vali mean dice is: 0.5115	vali mean IoU is: 0.4370
#
# Epoch 53/100
#  ==================================================>	100.00%
# train dice loss is: 0.2810	train mean dice is: 0.7195	train mean IoU is: 0.6238
# vali dice loss is: 0.4970	vali mean dice is: 0.4938	vali mean IoU is: 0.4174
#
# Epoch 54/100
#  ==================================================>	100.00%
# train dice loss is: 0.2781	train mean dice is: 0.7221	train mean IoU is: 0.6266
# vali dice loss is: 0.5145	vali mean dice is: 0.4855	vali mean IoU is: 0.3837
#
# Epoch 55/100
#  ==================================================>	100.00%
# train dice loss is: 0.2723	train mean dice is: 0.7278	train mean IoU is: 0.6339
# vali dice loss is: 0.4389	vali mean dice is: 0.5593	vali mean IoU is: 0.4704
#
# Epoch 56/100
#  ==================================================>	100.00%
# train dice loss is: 0.2625	train mean dice is: 0.7379	train mean IoU is: 0.6459
# vali dice loss is: 0.4810	vali mean dice is: 0.5168	vali mean IoU is: 0.4292
#
# Epoch 57/100
#  ==================================================>	100.00%
# train dice loss is: 0.2488	train mean dice is: 0.7516	train mean IoU is: 0.6630
# vali dice loss is: 0.4705	vali mean dice is: 0.5412	vali mean IoU is: 0.4628
#
# Epoch 58/100
#  ==================================================>	100.00%
# train dice loss is: 0.2530	train mean dice is: 0.7474	train mean IoU is: 0.6565
# vali dice loss is: 0.4541	vali mean dice is: 0.5420	vali mean IoU is: 0.4615
#
# Epoch 59/100
#  ==================================================>	100.00%
# train dice loss is: 0.2550	train mean dice is: 0.7454	train mean IoU is: 0.6546
# vali dice loss is: 0.4982	vali mean dice is: 0.5041	vali mean IoU is: 0.4316
#
# Epoch 60/100
#  ==================================================>	100.00%
# train dice loss is: 0.2465	train mean dice is: 0.7538	train mean IoU is: 0.6619
# vali dice loss is: 0.4627	vali mean dice is: 0.5367	vali mean IoU is: 0.4518
#
# Epoch 61/100
#  ==================================================>	100.00%
# train dice loss is: 0.2414	train mean dice is: 0.7589	train mean IoU is: 0.6673
# vali dice loss is: 0.5287	vali mean dice is: 0.4695	vali mean IoU is: 0.3736
#
# Epoch 62/100
#  ==================================================>	100.00%
# train dice loss is: 0.2536	train mean dice is: 0.7468	train mean IoU is: 0.6525
# vali dice loss is: 0.4312	vali mean dice is: 0.5662	vali mean IoU is: 0.4856
#
# Epoch 63/100
#  ==================================================>	100.00%
# train dice loss is: 0.2420	train mean dice is: 0.7586	train mean IoU is: 0.6645
# vali dice loss is: 0.4408	vali mean dice is: 0.5597	vali mean IoU is: 0.4782
#
# Epoch 64/100
#  ==================================================>	100.00%
# train dice loss is: 0.2339	train mean dice is: 0.7665	train mean IoU is: 0.6762
# vali dice loss is: 0.4544	vali mean dice is: 0.5476	vali mean IoU is: 0.4701
#
# Epoch 65/100
#  ==================================================>	100.00%
# train dice loss is: 0.2169	train mean dice is: 0.7835	train mean IoU is: 0.6954
# vali dice loss is: 0.4638	vali mean dice is: 0.5322	vali mean IoU is: 0.4447
#
# Epoch 66/100
#  ==================================================>	100.00%
# train dice loss is: 0.2319	train mean dice is: 0.7684	train mean IoU is: 0.6774
# vali dice loss is: 0.4453	vali mean dice is: 0.5530	vali mean IoU is: 0.4661
#
# Epoch 67/100
#  ==================================================>	100.00%
# train dice loss is: 0.2401	train mean dice is: 0.7604	train mean IoU is: 0.6667
# vali dice loss is: 0.4567	vali mean dice is: 0.5551	vali mean IoU is: 0.4699
#
# Epoch 68/100
#  ==================================================>	100.00%
# train dice loss is: 0.2390	train mean dice is: 0.7613	train mean IoU is: 0.6689
# vali dice loss is: 0.4511	vali mean dice is: 0.5457	vali mean IoU is: 0.4620
#
# Epoch 69/100
#  ==================================================>	100.00%
# train dice loss is: 0.2166	train mean dice is: 0.7836	train mean IoU is: 0.6961
# vali dice loss is: 0.4526	vali mean dice is: 0.5471	vali mean IoU is: 0.4641
#
# Epoch 70/100
#  ==================================================>	100.00%
# train dice loss is: 0.2077	train mean dice is: 0.7927	train mean IoU is: 0.7065
# vali dice loss is: 0.4777	vali mean dice is: 0.5099	vali mean IoU is: 0.4441
#
# Epoch 71/100
#  ==================================================>	100.00%
# train dice loss is: 0.2054	train mean dice is: 0.7948	train mean IoU is: 0.7108
# vali dice loss is: 0.4560	vali mean dice is: 0.5496	vali mean IoU is: 0.4665
#
# Epoch 72/100
#  ==================================================>	100.00%
# train dice loss is: 0.2046	train mean dice is: 0.7958	train mean IoU is: 0.7098
# vali dice loss is: 0.4582	vali mean dice is: 0.5463	vali mean IoU is: 0.4685
#
# Epoch 73/100
#  ==================================================>	100.00%
# train dice loss is: 0.2044	train mean dice is: 0.7957	train mean IoU is: 0.7114
# vali dice loss is: 0.4424	vali mean dice is: 0.5553	vali mean IoU is: 0.4754
#
# Epoch 74/100
#  ==================================================>	100.00%
# train dice loss is: 0.2044	train mean dice is: 0.7959	train mean IoU is: 0.7122
# vali dice loss is: 0.4289	vali mean dice is: 0.5667	vali mean IoU is: 0.4805
#
# Epoch 75/100
#  ==================================================>	100.00%
# train dice loss is: 0.2035	train mean dice is: 0.7968	train mean IoU is: 0.7131
# vali dice loss is: 0.4650	vali mean dice is: 0.5374	vali mean IoU is: 0.4568
#
# Epoch 76/100
#  ==================================================>	100.00%
# train dice loss is: 0.2087	train mean dice is: 0.7918	train mean IoU is: 0.7058
# vali dice loss is: 0.4984	vali mean dice is: 0.5034	vali mean IoU is: 0.4387
#
# Epoch 77/100
#  ==================================================>	100.00%
# train dice loss is: 0.2187	train mean dice is: 0.7815	train mean IoU is: 0.6922
# vali dice loss is: 0.4686	vali mean dice is: 0.5291	vali mean IoU is: 0.4415
#
# Epoch 78/100
#  ==================================================>	100.00%
# train dice loss is: 0.2314	train mean dice is: 0.7688	train mean IoU is: 0.6751
# vali dice loss is: 0.4829	vali mean dice is: 0.5181	vali mean IoU is: 0.4422
#
# Epoch 79/100
#  ==================================================>	100.00%
# train dice loss is: 0.2184	train mean dice is: 0.7817	train mean IoU is: 0.6936
# vali dice loss is: 0.4382	vali mean dice is: 0.5633	vali mean IoU is: 0.4776
#
# Epoch 80/100
#  ==================================================>	100.00%
# train dice loss is: 0.2157	train mean dice is: 0.7847	train mean IoU is: 0.6976
# vali dice loss is: 0.4492	vali mean dice is: 0.5558	vali mean IoU is: 0.4685
#
# Epoch 81/100
#  ==================================================>	100.00%
# train dice loss is: 0.2194	train mean dice is: 0.7806	train mean IoU is: 0.6909
# vali dice loss is: 0.4393	vali mean dice is: 0.5584	vali mean IoU is: 0.4742
#
# Epoch 82/100
#  ==================================================>	100.00%
# train dice loss is: 0.2059	train mean dice is: 0.7945	train mean IoU is: 0.7090
# vali dice loss is: 0.4733	vali mean dice is: 0.5310	vali mean IoU is: 0.4560
#
# Epoch 83/100
#  ==================================================>	100.00%
# train dice loss is: 0.1988	train mean dice is: 0.8014	train mean IoU is: 0.7176
# vali dice loss is: 0.4416	vali mean dice is: 0.5538	vali mean IoU is: 0.4714
#
# Epoch 84/100
#  ==================================================>	100.00%
# train dice loss is: 0.1927	train mean dice is: 0.8077	train mean IoU is: 0.7264
# vali dice loss is: 0.4642	vali mean dice is: 0.5383	vali mean IoU is: 0.4637
#
# Epoch 85/100
#  ==================================================>	100.00%
# train dice loss is: 0.1956	train mean dice is: 0.8049	train mean IoU is: 0.7211
# vali dice loss is: 0.4531	vali mean dice is: 0.5507	vali mean IoU is: 0.4744
#
# Epoch 86/100
#  ==================================================>	100.00%
# train dice loss is: 0.1812	train mean dice is: 0.8190	train mean IoU is: 0.7402
# vali dice loss is: 0.4296	vali mean dice is: 0.5692	vali mean IoU is: 0.4888
#
# Epoch 87/100
#  ==================================================>	100.00%
# train dice loss is: 0.1879	train mean dice is: 0.8125	train mean IoU is: 0.7321
# vali dice loss is: 0.4769	vali mean dice is: 0.5262	vali mean IoU is: 0.4526
#
# Epoch 88/100
#  ==================================================>	100.00%
# train dice loss is: 0.1934	train mean dice is: 0.8068	train mean IoU is: 0.7252
# vali dice loss is: 0.4718	vali mean dice is: 0.5306	vali mean IoU is: 0.4569
#
# Epoch 89/100
#  ==================================================>	100.00%
# train dice loss is: 0.1954	train mean dice is: 0.8049	train mean IoU is: 0.7230
# vali dice loss is: 0.4914	vali mean dice is: 0.5105	vali mean IoU is: 0.4418
#
# Epoch 90/100
#  ==================================================>	100.00%
# train dice loss is: 0.1874	train mean dice is: 0.8129	train mean IoU is: 0.7331
# vali dice loss is: 0.4494	vali mean dice is: 0.5560	vali mean IoU is: 0.4818
#
# Epoch 91/100
#  ==================================================>	100.00%
# train dice loss is: 0.1846	train mean dice is: 0.8157	train mean IoU is: 0.7359
# vali dice loss is: 0.4668	vali mean dice is: 0.5371	vali mean IoU is: 0.4505
#
# Epoch 92/100
#  ==================================================>	100.00%
# train dice loss is: 0.1860	train mean dice is: 0.8143	train mean IoU is: 0.7333
# vali dice loss is: 0.4379	vali mean dice is: 0.5663	vali mean IoU is: 0.4831
#
# Epoch 93/100
#  ==================================================>	100.00%
# train dice loss is: 0.1850	train mean dice is: 0.8152	train mean IoU is: 0.7373
# vali dice loss is: 0.4504	vali mean dice is: 0.5511	vali mean IoU is: 0.4813
#
# Epoch 94/100
#  ==================================================>	100.00%
# train dice loss is: 0.1998	train mean dice is: 0.8011	train mean IoU is: 0.7170
# vali dice loss is: 0.4497	vali mean dice is: 0.5487	vali mean IoU is: 0.4674
#
# Epoch 95/100
#  ==================================================>	100.00%
# train dice loss is: 0.1866	train mean dice is: 0.8137	train mean IoU is: 0.7321
# vali dice loss is: 0.4288	vali mean dice is: 0.5672	vali mean IoU is: 0.4868
#
# Epoch 96/100
#  ==================================================>	100.00%
# train dice loss is: 0.1853	train mean dice is: 0.8150	train mean IoU is: 0.7337
# vali dice loss is: 0.4312	vali mean dice is: 0.5735	vali mean IoU is: 0.4931
#
# Epoch 97/100
#  ==================================================>	100.00%
# train dice loss is: 0.1864	train mean dice is: 0.8140	train mean IoU is: 0.7326
# vali dice loss is: 0.4574	vali mean dice is: 0.5445	vali mean IoU is: 0.4711
#
# Epoch 98/100
#  ==================================================>	100.00%
# train dice loss is: 0.1819	train mean dice is: 0.8182	train mean IoU is: 0.7406
# vali dice loss is: 0.4315	vali mean dice is: 0.5652	vali mean IoU is: 0.4858
#
# Epoch 99/100
#  ==================================================>	100.00%
# train dice loss is: 0.1795	train mean dice is: 0.8206	train mean IoU is: 0.7422
# vali dice loss is: 0.4504	vali mean dice is: 0.5499	vali mean IoU is: 0.4711
#
# Epoch 100/100
#  ==================================================>	100.00%
# train dice loss is: 0.1686	train mean dice is: 0.8318	train mean IoU is: 0.7567
# vali dice loss is: 0.4524	vali mean dice is: 0.5439	vali mean IoU is: 0.4751
#
# Costs 5004.405358791351s.

# %%
plt.figure()
x = range(1, true_epoch+1)
# print(true_epoch)
loss1, loss2 = train_loss_list, vali_loss_list
# print(loss1)
plt.title(f'train loss vs vali loss, epoch={true_epoch}, learning rate={learning_rate}, optimizer=Adam')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.plot(x, loss1, label='train loss')
plt.plot(x, loss2, label='vali loss')
plt.legend()
plt.savefig('./Adam_0.01/loss_plot.png')
plt.show()

# %%
plt.figure()
x = range(1, true_epoch+1)
# print(true_epoch)
loss1, loss2 = train_dice_list, vali_dice_list
# print(loss1)
plt.title(f'train dice vs vali dice, epoch={true_epoch}, learning rate={learning_rate}, optimizer=Adam')
plt.xlabel('epoch')
plt.ylabel('dice score')
plt.plot(x, loss1, label='train dice')
plt.plot(x, loss2, label='vali dice')
plt.legend()
plt.savefig('./Adam_0.01/dice_plot.png')
plt.show()

# %%
plt.figure()
x = range(1, true_epoch+1)
# print(true_epoch)
loss1, loss2 = train_iou_list, vali_iou_list
# print(loss1)
plt.title(f'train IoU vs vali IoU, epoch={true_epoch}, learning rate={learning_rate}, optimizer=Adam')
plt.xlabel('epoch')
plt.ylabel('IoU')
plt.plot(x, loss1, label='train IoU')
plt.plot(x, loss2, label='vali IoU')
plt.legend()
plt.savefig('./Adam_0.01/IoU_plot.png')
plt.show()

# %%
import os
class TestKit19Set(Dataset):
    def __init__(self, datapath, new_size, augmentation=None, preprocessing=None):
        self.datapath = datapath
        self.new_size = new_size
        self.augmentation = augmentation
        self.preprocessing = preprocessing

    def __getitem__(self, i):
        input_img_path = self.datapath+f"/case_{i+210:05d}/imaging.nii.gz"
        # input_seg_path = self.datapath+f"/case_{i:05d}/segmentation.nii.gz"

        input_image = sitk.ReadImage(input_img_path)
        # print(type(input_image))

        # Get the current spacing and size of the input image
        input_spacing = input_image.GetSpacing()
        input_size = input_image.GetSize()

        # Compute the desired spacing based on the new size
        new_spacing = [old_sz * old_spc / new_sz for old_sz, old_spc, new_sz in
                       zip(input_size, input_spacing, self.new_size)]

        # Create the resampling transformation
        resampler = sitk.ResampleImageFilter()
        resampler.SetSize(self.new_size)
        resampler.SetOutputSpacing(new_spacing)
        resampler.SetOutputOrigin(input_image.GetOrigin())
        resampler.SetOutputDirection(input_image.GetDirection())

        # Perform the resampling
        output_image = resampler.Execute(input_image)
        # folder_path = f"/test_visual/case_{i + 210:05d}"
        # if not os.path.exists(folder_path):
            # os.makedirs(folder_path)
        output_filename = f"./test_visual/case_{i + 210:05d}/imaging.nii.gz"
        sitk.WriteImage(output_image, output_filename)
        output_image = sitk.GetArrayFromImage(output_image)
        output_image = output_image.astype(np.float32)
        output_image = np.transpose(output_image, (2, 1, 0))

        return output_image
        # return output_image, output_mask

    def __len__(self):
        return int(90)

# %%
test_set = TestKit19Set("data", new_size=[64, 256, 256])
test_loader = DataLoader(test_set, batch_size=1, shuffle=False)

# %%
device = torch.device("cuda")
model = UNet3D()
model.load_state_dict(torch.load("./work/new_best_model_3.pth"))

model.to(device)

from tqdm.notebook import tqdm_notebook
torch.cuda.empty_cache()
tqdm_notebook.monitor_interval = 0
for i, img in tqdm_notebook(enumerate(test_loader),desc="Batch progress", leave=False):
    with torch.no_grad():
        img = img.unsqueeze(1).to(device)
        # print(img.shape)
        out = model(img)
        # print(out.shape)
        out = torch.squeeze(out)
        out = out.permute(0,3,1,2)
        # print(out.shape)
        # print(out.shape)
        # print(out[0,24,24,24], out[1,24,24,24],out[2,24,24,24])
        # print(out[0, 36, 36, 36], out[1, 36, 36, 36], out[2, 36, 36, 36])
        # the output shape is [3, 64, 128,128]

        out = torch.argmax(out, dim=0)
        # the shape will be [64,128,128]
        # print(out.shape)
        # is_all_zero = torch.all(out == 0)
        # print("Is the tensor all zero?", is_all_zero)
        # print(out.shape)
        # unique = np.unique(out)
        # print(len(unique))
        
        out = out.cpu()
        out = out.detach().numpy()
        out = np.transpose(out, (2, 1, 0))
        # unique = np.unique(out)
        # print(out.shape)
        out = sitk.GetImageFromArray(out)
        # print(out.GetSize(), type(out))
        output_filename = f"./test_visual/case_{i+210:05d}/segmentation.nii.gz"
        # print(output_filename)
        sitk.WriteImage(out, output_filename)
# Out:
# Batch progress: 0it [00:00, ?it/s]
